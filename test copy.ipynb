# %%
## 대사 추출하기
import re
import csv
import io

# %%
def extract_dialogue_from_txt(script_text):
    """
    주어진 스크립트 텍스트(.txt)에서 대사만 추출하여 리스트로 반환합니다.
    형식: 이름이 한 줄에 나오고 다음 줄부터 대사가 나오는 형식 및
          이름 : 대사 형식 등을 처리하려고 시도합니다.

    Args:
        script_text (str): 영화 대본 텍스트.

    Returns:
        list: [{'Character': 이름, 'Dialogue': 대사}, ...] 형식의 딕셔너리 리스트.
              추출 실패 시 빈 리스트 반환.
    """
    dialogues = []
    lines = script_text.strip().split('\n')

    i = 0
    while i < len(lines):
        line = lines[i].strip()

        # 비어있거나 씬 넘버(#숫자.) 인 경우 건너뜀
        if not line or line.startswith('#') or re.match(r'^#\d+\.', line):
            i += 1
            continue

        # 이름 후보: 주로 한글, 짧은 길이, 콜론(:) 없음, 괄호 설명 가능성 (V.O) 등
        # 이 부분은 대본 형식에 따라 매우 가변적이므로, 완벽하지 않을 수 있습니다.
        # 여기서는 이름이 단독 라인에 있을 가능성을 먼저 봅니다.
        potential_name_match = re.match(r'^([가-힣]+(?:\s*\([^)]+\))?)$', line)

        if potential_name_match and (i + 1 < len(lines)):
            character_name = potential_name_match.group(1).strip()
            # 다음 줄이 대사인지 확인 (빈 줄이 아니고, 다른 이름/씬넘버 패턴이 아닌 경우)
            next_line_index = i + 1
            while next_line_index < len(lines) and not lines[next_line_index].strip():
                next_line_index += 1 # 빈 줄 건너뛰기

            if next_line_index < len(lines):
                next_line = lines[next_line_index].strip()
                is_next_line_name = bool(re.match(r'^([가-힣]+(?:\s*\([^)]+\))?)$', next_line))
                is_scene_heading = next_line.startswith('#') or re.match(r'^#\d+\.', next_line)

                # 다음 줄이 이름이나 씬넘버가 아니라면 대사로 간주
                if not is_next_line_name and not is_scene_heading:
                    current_dialogue_lines = []
                    dialogue_line_index = next_line_index
                    while dialogue_line_index < len(lines):
                        dialogue_part = lines[dialogue_line_index].strip()
                        # 다음 줄이 새로운 이름/씬넘버/빈줄이 아니면 대사 연속으로 간주
                        is_dialogue_name_follow = bool(re.match(r'^([가-힣]+(?:\s*\([^)]+\))?)$', dialogue_part))
                        is_scene_heading_follow = dialogue_part.startswith('#') or re.match(r'^#\d+\.', dialogue_part)

                        if not dialogue_part or is_dialogue_name_follow or is_scene_heading_follow:
                            break # 대사 끝

                        current_dialogue_lines.append(dialogue_part)
                        dialogue_line_index += 1

                    if current_dialogue_lines:
                        full_dialogue = " ".join(current_dialogue_lines).strip()
                        # 괄호 안 지문/설명 제거 (예: (웃으며) 제거)
                        cleaned_dialogue = re.sub(r'\([^)]*\)', '', full_dialogue).strip()
                        # 여러 공백을 하나로 변경
                        cleaned_dialogue = ' '.join(cleaned_dialogue.split())

                        if cleaned_dialogue:
                            dialogues.append({
                                'Character': character_name,
                                'Dialogue': cleaned_dialogue
                            })
                        i = dialogue_line_index # 다음 처리할 라인 인덱스 업데이트
                        continue # 다음 루프로

        # 이름 : 대사 형식도 확인
        dialogue_colon_match = re.match(r'^\s*([^:\n]+?)\s*:\s*(.*)', line)
        if dialogue_colon_match:
             character_name = dialogue_colon_match.group(1).strip()
             dialogue_text = dialogue_colon_match.group(2).strip()
             # 괄호 안 지문/설명 제거
             cleaned_dialogue = re.sub(r'\([^)]*\)', '', dialogue_text).strip()
             cleaned_dialogue = ' '.join(cleaned_dialogue.split())
             if cleaned_dialogue:
                 dialogues.append({
                     'Character': character_name,
                     'Dialogue': cleaned_dialogue
                 })
             i += 1
             continue # 다음 루프로

        # 위 패턴에 맞지 않으면 다음 줄로 이동
        i += 1

    return dialogues

# %%
def extract_dialogue_tab_format(script_text):
    """
    주어진 스크립트 텍스트에서 대사만 추출하여 리스트로 반환합니다.
    형식: '이름\t대사' 및 '\t대사' (연속 줄) 형식을 처리합니다.

    Args:
        script_text (str): 영화 대본 텍스트.

    Returns:
        list: [{'Character': 이름, 'Dialogue': 대사}, ...] 형식의 딕셔너리 리스트.
              추출 실패 시 빈 리스트 반환.
    """
    dialogues = []
    lines = script_text.strip().split('\n')

    current_character = None
    current_dialogue_lines = []

    # 이름 TAB 대사 패턴
    dialogue_start_re = re.compile(r'^([^\t\n]+)\t(.*)')
    # TAB 대사 (연속) 패턴
    continuation_re = re.compile(r'^\t(.*)')
    # 씬 넘버 패턴 (숫자. 으로 시작)
    scene_re = re.compile(r'^\d+\.\s+')
    # 괄호 안의 지문/설명 제거 패턴
    action_re = re.compile(r'\([^)]*\)')

    for line in lines:
        line_stripped = line.strip() # 앞뒤 공백 제거 후 내용 확인용
        
        # 빈 줄 또는 씬 넘버 건너뛰기
        if not line_stripped or scene_re.match(line):
            # 이전 대사가 있었다면 저장
            if current_character and current_dialogue_lines:
                full_dialogue = " ".join(current_dialogue_lines).strip()
                cleaned_dialogue = action_re.sub('', full_dialogue).strip()
                cleaned_dialogue = ' '.join(cleaned_dialogue.split())
                if cleaned_dialogue:
                    dialogues.append({
                        'Character': current_character,
                        'Dialogue': cleaned_dialogue
                    })
            current_character = None
            current_dialogue_lines = []
            continue

        match_start = dialogue_start_re.match(line) # 원본 라인으로 매칭 (탭 확인 위해)
        match_cont = continuation_re.match(line) # 원본 라인으로 매칭 (탭 확인 위해)

        if match_start:
            # 이전 대사가 있었다면 저장
            if current_character and current_dialogue_lines:
                full_dialogue = " ".join(current_dialogue_lines).strip()
                cleaned_dialogue = action_re.sub('', full_dialogue).strip()
                cleaned_dialogue = ' '.join(cleaned_dialogue.split())
                if cleaned_dialogue:
                    dialogues.append({
                        'Character': current_character,
                        'Dialogue': cleaned_dialogue
                    })
            
            # 새 대사 시작
            current_character = match_start.group(1).strip()
            initial_dialogue = match_start.group(2).strip()
            current_dialogue_lines = [initial_dialogue] if initial_dialogue else []

        elif match_cont and current_character:
            # 대사 연속
            continuation_text = match_cont.group(1).strip()
            if continuation_text:
                current_dialogue_lines.append(continuation_text)
                
        else: # 지문 또는 다른 형식의 라인
            # 이전 대사가 있었다면 저장
            if current_character and current_dialogue_lines:
                full_dialogue = " ".join(current_dialogue_lines).strip()
                cleaned_dialogue = action_re.sub('', full_dialogue).strip()
                cleaned_dialogue = ' '.join(cleaned_dialogue.split())
                if cleaned_dialogue:
                    dialogues.append({
                        'Character': current_character,
                        'Dialogue': cleaned_dialogue
                    })
            current_character = None
            current_dialogue_lines = []

    # 마지막 대사 블록 처리
    if current_character and current_dialogue_lines:
        full_dialogue = " ".join(current_dialogue_lines).strip()
        cleaned_dialogue = action_re.sub('', full_dialogue).strip()
        cleaned_dialogue = ' '.join(cleaned_dialogue.split())
        if cleaned_dialogue:
            dialogues.append({
                'Character': current_character,
                'Dialogue': cleaned_dialogue
            })

    return dialogues

# %%
def extract_dialogue_colon_format(script_text):
    """
    주어진 스크립트 텍스트에서 대사만 추출하여 리스트로 반환합니다.
    형식: '이름 : 대사' 형식을 주로 처리합니다.

    Args:
        script_text (str): 영화 대본 텍스트.

    Returns:
        list: [{'Character': 이름, 'Dialogue': 대사}, ...] 형식의 딕셔너리 리스트.
              추출 실패 시 빈 리스트 반환.
    """
    dialogues = []
    lines = script_text.strip().split('\n')

    # 이름 : 대사 패턴 (이름에 괄호 설명 포함 가능)
    dialogue_re = re.compile(r'^\s*([^:\n]+?)\s*:\s*(.*)')
    # 씬 넘버 패턴
    scene_re = re.compile(r'^S#\s*\d+')
    # 괄호 안의 지문/설명 제거 패턴
    action_re = re.compile(r'\([^)]*\)')

    for line in lines:
        line_stripped = line.strip()

        # 빈 줄 또는 씬 넘버 건너뛰기
        if not line_stripped or scene_re.match(line):
            continue

        match = dialogue_re.match(line)
        if match:
            character_name = match.group(1).strip()
            dialogue_text = match.group(2).strip()

            # 이름에 포함된 (V.O), (off) 등은 유지할 수 있으나,
            # 대사 중의 (놀란듯), (엔지니어에게) 등은 제거
            cleaned_dialogue = action_re.sub('', dialogue_text).strip()
            # 여러 공백을 하나로 정리
            cleaned_dialogue = ' '.join(cleaned_dialogue.split())

            if cleaned_dialogue: # 내용이 있는 경우만 추가
                dialogues.append({
                    'Character': character_name,
                    'Dialogue': cleaned_dialogue
                })
        # else:
            # 연속 줄 처리 로직 추가 가능 (들여쓰기 등 기준 필요)
            # 이 예제에서는 '이름 : 대사' 형식만 처리합니다.

    return dialogues

# %%
def extract_dialogue_indented_final_v3(script_text):
    """
    주어진 스크립트 텍스트에서 대사만 추출하여 리스트로 반환합니다. (들여쓰기 활용 및 연속줄 처리 개선)
    형식: '    이름    대사' 형식 및 연속 줄 대사를 처리합니다.
          continuation_indent_re 변수를 실제로 활용합니다.

    Args:
        script_text (str): 영화 대본 텍스트.

    Returns:
        list: [{'Character': 이름, 'Dialogue': 대사}, ...] 형식의 딕셔너리 리스트.
    """
    dialogues = []
    # 원본 줄바꿈 유지, 페이지 넘김 문자는 제거
    lines = script_text.replace('\f', '').split('\n')

    # 이름+대사 시작 패턴: ^(들여쓰기)(이름)(공백+)(대사)
    dialogue_start_re = re.compile(r'^(\s+)([^\s].*?[^\s](?:\s*\([^)]+\))?)\s+(.+)')
    # 이름 없이 들여쓰기만 된 연속 대사/지문 패턴
    continuation_indent_re = re.compile(r'^(\s+)(.*)') # 들여쓰기 된 모든 줄
    # 씬 넘버 패턴
    scene_re = re.compile(r'^\d+\.\s+')
    # 괄호 안 지문 제거 패턴
    action_re = re.compile(r'\([^)]*\)')
    # 빈 줄 확인용
    empty_line_re = re.compile(r'^\s*$')

    current_character = None
    current_dialogue_lines = []
    last_indent_level = -1 # 마지막 대사 시작 줄의 들여쓰기 레벨

    for line in lines:
        stripped_line = line.strip()

        # 빈 줄 처리
        if not stripped_line:
            if current_character and current_dialogue_lines:
                full_dialogue = " ".join(current_dialogue_lines).strip()
                full_dialogue = ' '.join(full_dialogue.split())
                if full_dialogue:
                    dialogues.append({'Character': current_character, 'Dialogue': full_dialogue})
            current_character = None
            current_dialogue_lines = []
            last_indent_level = -1
            continue

        # 씬 넘버 처리
        if scene_re.match(stripped_line):
            if current_character and current_dialogue_lines:
                 full_dialogue = " ".join(current_dialogue_lines).strip()
                 full_dialogue = ' '.join(full_dialogue.split())
                 if full_dialogue:
                     dialogues.append({'Character': current_character, 'Dialogue': full_dialogue})
            current_character = None
            current_dialogue_lines = []
            last_indent_level = -1
            continue

        match_start = dialogue_start_re.match(line) # 이름 + 대사 시작 확인

        if match_start:
            # 이전 대사 저장
            if current_character and current_dialogue_lines:
                full_dialogue = " ".join(current_dialogue_lines).strip()
                full_dialogue = ' '.join(full_dialogue.split())
                if full_dialogue:
                    dialogues.append({'Character': current_character, 'Dialogue': full_dialogue})

            # 새 대사 시작
            current_indent = len(match_start.group(1))
            current_character = match_start.group(2).strip()
            initial_dialogue = match_start.group(3).strip()
            cleaned_part = action_re.sub('', initial_dialogue).strip()
            current_dialogue_lines = [cleaned_part] if cleaned_part else []
            last_indent_level = current_indent

        elif current_character: # 현재 화자가 있는 상태에서
            cont_match = continuation_indent_re.match(line) # <<-- continuation_indent_re 사용
            if cont_match:
                 current_line_indent = len(cont_match.group(1))
                 # 이전 대사 시작 줄보다 들여쓰기가 같거나 크고, 내용이 있다면 연속 대사로 간주
                 if current_line_indent >= last_indent_level:
                     continuation_text = cont_match.group(2).strip()
                     # 혹시 들여쓰기된 줄이 이름 패턴으로 시작하면 제외 (지문 등)
                     if not re.match(r'^[^\s].*?[^\s](?:\s*\([^)]+\))?\s+', continuation_text):
                         cleaned_part = action_re.sub('', continuation_text).strip()
                         if cleaned_part:
                             current_dialogue_lines.append(cleaned_part)
                     else: # 들여쓰기 됐지만 새 이름 패턴이면 이전 대사 저장
                          if current_character and current_dialogue_lines:
                              full_dialogue = " ".join(current_dialogue_lines).strip()
                              full_dialogue = ' '.join(full_dialogue.split())
                              if full_dialogue:
                                  dialogues.append({'Character': current_character, 'Dialogue': full_dialogue})
                          current_character = None
                          current_dialogue_lines = []
                          last_indent_level = -1
                 else: # 들여쓰기가 이전보다 작으면 지문으로 보고 이전 대사 저장
                     if current_character and current_dialogue_lines:
                          full_dialogue = " ".join(current_dialogue_lines).strip()
                          full_dialogue = ' '.join(full_dialogue.split())
                          if full_dialogue:
                              dialogues.append({'Character': current_character, 'Dialogue': full_dialogue})
                     current_character = None
                     current_dialogue_lines = []
                     last_indent_level = -1
            else: # 들여쓰기 없는 줄은 지문으로 보고 이전 대사 저장
                if current_character and current_dialogue_lines:
                     full_dialogue = " ".join(current_dialogue_lines).strip()
                     full_dialogue = ' '.join(full_dialogue.split())
                     if full_dialogue:
                         dialogues.append({'Character': current_character, 'Dialogue': full_dialogue})
                current_character = None
                current_dialogue_lines = []
                last_indent_level = -1
        # else: # 이름 패턴도 아니고, 현재 화자도 없으면 지문 (처리 없음)
        #     pass

    # 마지막 대사 블록 처리
    if current_character and current_dialogue_lines:
        full_dialogue = " ".join(current_dialogue_lines).strip()
        full_dialogue = ' '.join(full_dialogue.split())
        if full_dialogue:
            dialogues.append({'Character': current_character, 'Dialogue': full_dialogue})

    return dialogues

# %%
def extract_dialogue_enter_format(script_text):
    """
    주어진 스크립트 텍스트에서 대사만 추출하여 리스트로 반환합니다.
    형식: 이름이 한 줄에 나오고 다음 줄부터 대사가 나오는 형식을 처리합니다.

    Args:
        script_text (str): 영화 대본 텍스트.

    Returns:
        list: [{'Character': 이름, 'Dialogue': 대사}, ...] 형식의 딕셔너리 리스트.
              추출 실패 시 빈 리스트 반환.
    """
    dialogues = []
    lines = script_text.strip().split('\n')

    i = 0
    while i < len(lines):
        line = lines[i].strip()

        # 비어있거나 씬 넘버(#숫자. 또는 숫자.) 인 경우 건너뜀
        if not line or line.startswith('#') or re.match(r'^\d+\.\s+', line):
            i += 1
            continue

        # 이름 후보: 주로 한글, 짧은 길이, 콜론(:) 없음, 괄호 설명 가능성 (V.O), (소리) 등
        # 이름으로 간주할 수 있는 패턴 (좀 더 유연하게)
        # - 한글, 영문, 숫자, 공백, 괄호 포함 가능
        # - 너무 길지 않은 라인 (예: 30자 미만)
        # - 명확한 지문 형태가 아닌 경우 (예: '...를 지나치는데-' 로 끝나지 않는 경우)
        potential_name_match = re.match(r'^([^\t\n]{1,30})$', line) # 탭, 개행 제외 1~30자
        is_likely_action = line.endswith('는데-') or line.endswith('다.') or line.endswith('보인다.') or line.endswith('있다.') # 지문일 가능성이 높은 경우 제외

        if potential_name_match and not is_likely_action and (i + 1 < len(lines)):
            potential_character_name = line # 일단 현재 줄을 이름 후보로

            # 다음 줄이 대사인지 확인 (빈 줄이 아니고, 다른 이름/씬넘버 패턴이 아닌 경우)
            next_line_index = i + 1
            while next_line_index < len(lines) and not lines[next_line_index].strip():
                next_line_index += 1 # 빈 줄 건너뛰기

            if next_line_index < len(lines):
                next_line = lines[next_line_index].strip()
                # 다음 줄이 '이름' 후보 패턴과 일치하거나 씬 넘버로 시작하면 현재 줄은 이름이 아님
                is_next_line_name_candidate = bool(re.match(r'^([^\t\n]{1,30})$', next_line)) and not (next_line.endswith('는데-') or next_line.endswith('다.') or next_line.endswith('보인다.') or next_line.endswith('있다.'))
                is_scene_heading = next_line.startswith('#') or re.match(r'^\d+\.\s+', lines[next_line_index]) # 원본 줄 확인

                # 다음 줄이 새로운 이름 후보나 씬넘버가 아니라면 현재 줄을 이름으로 확정하고 대사 추출 시작
                if not is_next_line_name_candidate and not is_scene_heading:
                    character_name = potential_character_name # 이름 확정
                    current_dialogue_lines = []
                    dialogue_line_index = next_line_index

                    while dialogue_line_index < len(lines):
                        dialogue_part_raw = lines[dialogue_line_index] # 원본 줄 유지 (들여쓰기 등 확인 위함)
                        dialogue_part_stripped = dialogue_part_raw.strip()

                        # 다음 줄이 새로운 이름 후보거나 씬 넘버거나 빈 줄이면 대사 끝
                        is_dialogue_name_follow = bool(re.match(r'^([^\t\n]{1,30})$', dialogue_part_stripped)) and not (dialogue_part_stripped.endswith('는데-') or dialogue_part_stripped.endswith('다.') or dialogue_part_stripped.endswith('보인다.') or dialogue_part_stripped.endswith('있다.'))
                        is_scene_heading_follow = dialogue_part_stripped.startswith('#') or re.match(r'^\d+\.\s+', dialogue_part_raw)

                        if not dialogue_part_stripped or (is_dialogue_name_follow and not dialogue_part_raw.startswith('\t') and not dialogue_part_raw.startswith(' ')) or is_scene_heading_follow:
                             # 들여쓰기 없는 이름 후보는 새 이름으로 간주
                            break # 대사 끝

                        # 대사에 포함될 내용 (괄호 안 지문 제거)
                        cleaned_part = re.sub(r'\([^)]*\)', '', dialogue_part_stripped).strip()
                        if cleaned_part:
                            current_dialogue_lines.append(cleaned_part)
                        dialogue_line_index += 1

                    if current_dialogue_lines:
                        full_dialogue = " ".join(current_dialogue_lines).strip()
                        # 여러 공백을 하나로 변경
                        full_dialogue = ' '.join(full_dialogue.split())

                        if full_dialogue:
                            dialogues.append({
                                'Character': character_name,
                                'Dialogue': full_dialogue
                            })
                        i = dialogue_line_index # 다음 처리할 라인 인덱스 업데이트
                        continue # 다음 바깥 루프로

        # '이름 : 대사' 형식도 혹시 모르니 체크 (혼용 가능성)
        dialogue_colon_match = re.match(r'^\s*([^:\n]+?)\s*:\s*(.*)', line)
        if dialogue_colon_match:
             character_name = dialogue_colon_match.group(1).strip()
             dialogue_text = dialogue_colon_match.group(2).strip()
             cleaned_dialogue = re.sub(r'\([^)]*\)', '', dialogue_text).strip()
             cleaned_dialogue = ' '.join(cleaned_dialogue.split())
             if cleaned_dialogue:
                 # 이름만 있는 줄 다음 대사가 오는 형식을 우선하므로, 중복 방지 체크 필요 시 추가
                 # 예: if not dialogues or dialogues[-1]['Character'] != character_name:
                 dialogues.append({
                     'Character': character_name,
                     'Dialogue': cleaned_dialogue
                 })
             i += 1
             continue # 다음 루프로

        # 위 패턴에 모두 맞지 않으면 다음 줄로 이동
        i += 1

    return dialogues

# %%
with open('../data/꽃피는봄이오면(2004-02-09).csv', 'r', encoding='utf-8') as f:
    script_content = ''.join(f.readlines())

extracted_dialogues = extract_dialogue_enter_format(script_content)    



# 4. 결과 확인 (예: CSV 형태로 출력)
if extracted_dialogues:
    output = io.StringIO()
    writer = csv.writer(output, quoting=csv.QUOTE_ALL)
    writer.writerow(['Character', 'Dialogue']) # 헤더 작성
    for entry in extracted_dialogues:
        writer.writerow([entry['Character'], entry['Dialogue']])

    csv_output = output.getvalue()
    output.close()
    print("--- CSV 출력 ---")
    print(csv_output)

    # 파일로 저장하고 싶을 경우:
    with open("../data/[대본]꽃피는봄이오면.csv", "w", encoding="utf-8", newline="") as f:
         f.write(csv_output)
    print("\nCSV 파일 '[대본]꽃피는봄이오면.csv 생성 완료.")

else:
    print("추출된 대사가 없습니다. 스크립트 형식을 확인해주세요.")
# Out:
# --- CSV 출력 ---
# "Character","Dialogue"
# "S# 1. 구청 관악반 - 오후 (비)","빈 복도. 낡은 창 밖으로 조각 풍경들이 보인다."
# "창에 부딪치는 빗방울들 위로 들리는 어색한 연주소리.","""동네 가게 아줌마서부터, 제법 차려입은 예쁜 아줌마들까지 섞여 있는, "" 썰렁한 동네 구청 한 구석의 아줌마들 대상 색소폰 교습반."
# "비 내리는 창 밖을 내다보고 있는 현우.","현우 : 영재슈퍼 사모님…. 자꾸 한 박자씩 늦으시네요."
# """현우","연주라는 건, 악기와 몸을 빌려서 마음으로 연주를 하는 거예요. """
# "따뜻한 사랑을 상상하세요. 댁에 계시는 남편분들이나.","아줌마들 표정이 갑자기 침울해진다. 그래도 배워보겠다는 자세로 불어보는데 소리가 더 안좋다."
# """현우","아… 아니, 아니, """
# "아줌마들 : …….","""현우 : 비 올 때 우산도 씌워주고, 비 맞으면서 기다리고, 같이 걷고…."" 그러던 첫사랑의 추억 다 있으시죠? 남편분들 말구요."
# "현우","자 그럼…."
# "그 첫사랑을 만진다고 생각하면서 손가락을 움직여보세요.","""“어머 어머, 못하는 소리가 없어 정말” 하면서도, "" 몇몇 아줌마들은 벌써 볼을 붉히며 살며시 입술을 색소폰에 가져간다."
# "경수","할만 해?"
# "현우","……."
# "경수","잘 생각했다. 어머니 고생하시는데."
# "현우","표정은 다 장영주야."
# "경수","재밌겠네 뭐…."
# "현우 : (한숨) … 재미없어.","그냥 아줌마들 좋아하는 얘기 대충 하면서 시간만 때우는 거지. 경수 : 그거라도 감지덕지 해. 요즘 일자리 없어서 난리들인데."
# "현우 : …….","현우의 전화가 울린다. 현우는 주머니에서 전화기를 꺼내 발신번호를 잠시 보고 있더니 받지 않는다."
# "전화 안받는 현우를 보는 경수.","경수 : 좀 받아라. 넌 뭐 그렇게 죄진 게 많냐?"
# "현우","됐어."
# "경수","전화 건 사람이 죽어가면서 한 거면 어쩔려구?"
# """현우 : 새끼, 재수 없게….""","전화벨 소리가 시끄러운지 사람들이 쳐다보기 시작한다."
# "현우","……."
# "연희","…… 오빠?"
# "밤 풍경들.","어두운 화단 한구석에 퍼질러 앉아서 전화기를 만지고 있는 여자."
# "화장을 진하게 하고 술이 조금 취한 연희.","길가는 사람들이 쳐다보고 지나간다."
# "현우","……."
# "연희","오랜만이네. 우리 오빠."
# "현우","……."
# "연희 : …….","현우 : 누가 보면 술집 아가씬줄 알겠다. 연희 : 누가 나 같은 아줌마를 써주냐? 써주면 영광이지."
# "현우 : …….","""연희 : 남자랑 술 먹었다, 나. 자기 통장 비밀번호가 내 생일이래. "" 오빠랑 똑같지?"
# "현우","그 자식 계좌번호가 어떻게 되냐?"
# "연희","… 착한 사람이야."
# "현우 : …….","문득 현우의 얼굴에 속도감시 카메라의 하얀 불빛이 팍 터진다."
# "끽-!","현우는 길가에 차를 세우고 잠시 숨을 고르며 참고 있더니 문을 열어젖히고 나간다."
# "연희 : (나가려는 현우를 붙잡으며) 왜 그래?","""현우 : 놔 봐…, 알았어, 놔 보라니까? 놔 봐, 글쎄."""
# "반쯤은 부서진 채 대롱대롱 매달려 있는 카메라.","백미러를 통해 현우의 그런 짓을 걱정스럽게 보고 있는 연희."
# "오래된 아파트 단지의 놀이터 벤치에 앉아있는 두 사람.","무슨 노래인지 모를 단순한 노랫가락을 콧노래로 흥얼대는 연희."
# "조금 슬픈 노랫가락.","다음 소절 생각이 안 나는지 자꾸만 같은 곳을 반복하고 있다."
# """현우 : 하지 마, 그거. ""","연희 : 좋아서 하나 뭐? 우울해지면 그냥 생각나. 곡이 너무 우울해서. 이젠 잘 기억도 안 나고 자꾸 틀리네."
# "현우","……."
# "연희 : 그땐 우리가 참 많이 사랑했었나봐.",""" 오빠, 한번만 불어줄래?"""
# "현우 : 욕먹어. 사람들 다 자는데.","""연희 : 아 참, 우리 오빠는 함부로 아무데서나 연주 안하지…. 미안. 또 까먹었네."""
# "현우","너 술을 도대체 얼마나 먹은 거야?"
# "연희","나…."
# "현우","…… ?"
# "연희","오빠가 준 목걸이 팔아서 술 먹었어."
# "연희","미안해."
# "현우 : 잘했어. 그 얘기 할려고 전화한 거야 ?","연희 : 그냥… 나 버린 남자랑 나 좋다는 남자랑 누가 더 나은가 비교해 볼려고."
# "현우","버리긴 뭘 버려. 누가 들으면 진짠줄 알겠네."
# "연희","그럼 버린 게 아님 뭐야?"
# "현우 : 음악만 하는 사람이랑은 못산다며.","연희 : 누가 음악하지 말래? 학원에서 애들도 가르치면서 얼마든지 할 수 있잖아."
# "현우","그만 하자. 왜 또 그래."
# "연희는 현우의 그런 모습에 익숙한 듯 대꾸도 없이","바짝 얼굴을 들이대고 현우의 얼굴을 찬찬히 살펴본다."
# "현우 : …….","연희 : 오빠두 많이 늙었다. 다행이야…. 나만 늙은 줄 알았는데."
# "일어나는 현우.","현우 : 무서우면 문 앞까지 같이 가줄까? 연희 : 내가 외로워 보여?"
# "현우","……."
# "연희는 현우의 뒷모습을 볼까봐 고개를 돌리고 앉아","잠시 벤치 옆의 나무를 보고 있다. 낙엽을 다 떨군 채 링겔을 하나 매달고 힘겹게 버티고 있는 나무."
# """현우, 걸음을 멈추고 뒤를 돌아보면 연희는 없고""","불 꺼진 아파트들 중에서 4층 작은 창에 불이 켜진다."
# "주방 탁자 위에 놓인 낡은 라디오에서","주부대상 퀴즈 프로그램이 나오고 있다."
# "라디오",": 화곡동. … 이번에 못 맞추시면 을지로가 기회를 뺏어갑니다."
# "엄마","화개장터."
# "현우","와- 엄마 알어?"
# "엄마 : 조영남이 맨날 부르는 게 그거잖아.","""라디오 :: 화개장터～ 딩동댕～ 자, 이제 2대2 … """
# "이삿짐을 꾸리고 있는 현우와 엄마.","엄마는 그릇들을 애 다루듯 살살 신문지에 겹겹이 싸고 있다."
# "무늬도 촌스런 꽃그림이 그려진 70년대풍 접시들.","현우 : 생전 가야 쓰지도 않는 걸 뭘 그렇게 싸? 그냥 버리지."
# "라디오",": 마지막 문제입니다."
# "①승부역 ②추전역 ③사북역 ④도계역","엄마 : 나중에 다 쓸 데 있지 왜 없어. 너 장가 가두 그릇 줘야 하구."
# "현우","요즘 그런 그릇을 누가 써. 촌스럽게."
# "엄마","……."
# """라디오",": …… 자, 5초 드리겠습니다. """
# "엄마","…… 어디니?"
# """현우","도계잖아, 도계. """
# "엄마 : …….","""라디오 :: … 을지로! … 네, 을지로… 2번 추전역!… 딩동댕…"""
# """엄마는 현우를 쳐다보고, 현우는 못 들은 척.""","부엌 서랍을 여는 현우. 그 안에 별 게 다 들어있다. 약간 지저분하기까지."
# "말없이 그릇을 싸고 있는 엄마.","라디오에서 트로트 노래가 나온다. 밝은 댄스풍의 트로트."
# "빤짝빤짝 임시번호판을 붙인","노란색 피아노학원 미니버스가 달리고 있다."
# "운전하는 경수. 그 옆 보조석에 앉은 현우.","""버스 뒤에서 재잘거리는, 교복을 입은 예쁜 여학생들의 다리를 훔쳐보는 현우. """
# """경수 : 야, 너 뭐 봐?""","""현우 : 쟤네들은, 지들이 다 무슨 훌륭한 연주가라도 될 줄 알고 있겠지?"""
# "경수","…"
# "현우 : 넌 쟤들이 다 돈으로 보이겠다?",""" 쟤는 올 연말 휴가비, 고 옆에 애는 한달 기름값, 고 옆에 애는…. """
# "경수 : 다 들려.","""현우 : 차도 사고, 돈도 많이 벌고, 좋겠다. """
# "경수","그러는 너는…."
# "현우","나? 나 뭐? 난 아직 꿈이 있잖냐."
# "경수","꿈같은 소리 하고 자빠졌네."
# "오케스트라에서 너 같은 중늙은이를 누가 써주냐?…",""" 지금까지 안됐으면 안 되는 거야, 임마. "" 포기해. 지는 동네 아줌마들하고 놀면서 뭘."
# "현우","……."
# "경수","나 지난달부터 연주해."
# "현우","?"
# "조금은 고급스러워 보이는 재즈바 풍의 술집.","구석 복도에는 술에 취해 부둥켜안고 춤을 추는 아줌마 아저씨 커플도 보인다. ""무대 위에서는 경수가 색소폰을 구성지게 불고 있는데,"""
# "가만히 들어보면 연희가 흥얼거리던 그 음악.","황당한 표정을 지으면서 무대 옆 테이블에 혼자 앉아있는 현우. 땀에 젖은 경수가 무대에서 내려와 현우 옆에 앉는다."
# "경수","하구 싶지? 해 그럼. 자."
# "현우","그걸 왜 니가 연주해?"
# "경수","왜? 서랍 속에 악보 짱박아 두면 뭐해."
# "현우","뭐?"
# "경수","너 여기 하루에 얼만 줄 알아?"
# "현우","천박하게 이런데서…."
# "경수","이 새끼 봐라. 뭐? 천박해?"
# "현우 : ……. (기분이 상한 듯 가방 들고 일어난다)","""경수 : 알았어, 알았어. 내 로얄티 주께. 그럼 됐지? "" 형님이 주는 돈이니까 받아라. 용돈 해. 돈도 없잖아 너. 사람이 돈도 있어야지."
# "현우","이게 점점… 애들 등이나 쳐먹는 새끼가…."
# "경수","뭐?"
# "싸늘하게 돌아서 가는 현우.","경수도 기분이 많이 상한 듯 그런 현우를 잡지 않는다."
# "S# 9. 현우 집 - 낮","마루에 TV가 혼자 켜져 있다."
# """화장실 문이 열려있고,""","변기 위에 앉아 담배를 피우며 음악잡지를 보고 있는 현우."
# """딸깍딸깍, 현관문이 열리며 누군가 들어온다. ""","엄마다. 피곤한 얼굴을 하고 있는 엄마. 뒤에 배낭을 메고 있다."
# "현우 : 왜?","엄마 : 너 또… 엄마가 이런 짓 하지 말랬지? "" 이럼 어떤 여자가 너 좋다고 하니? 아휴, 이 담배연기 좀 봐. "" "" 아니, 왜 똥 누는데 문 열어놓고 테레비를 틀어놓고 눠? "" 꼭 그래야 똥이 나오니?"
# "창이란 창은 모조리 다 여는 소리 들리고.","""현우, 신경도 안 쓰고 손으로 잡지 한 귀퉁이를 찍 찢어놓는다. """
# "현우 : 웬 떡?","""엄마 : 너 떡 좋아하는데, 그동안 못 사다줬네. 맛있니?"""
# "현우","……."
# """엄마","얘, 현우야. 이것 좀 고쳐봐라. """
# "마루에 놓은 엄마의 낡은 라디오.","엄마가 아무리 켜 보려고 해도 안 된다."
# "엄마","노래도 못 듣고 심심해서 못살겠네. 너 나가면 하루 종일 아무도 없고."
# "현우","왜 그래 또."
# "엄마","……. 이게 왜 이렇지?"
# "현우","이사 가면 주방에 라디오 있던데. 버리구 가 그냥."
# "엄마","……."
# "현우","경수 있잖아…. 술집에서 연주하더라?"
# "엄마","결혼하구 피아노학원 한다더니."
# "현우","그 자식 결혼하더니 순 돈독이 올라가지구."
# "그 새끼 거 원래 안 그랬는데….","엄마 : 너는 친구한테 그 새끼가 뭐니? 말을 이쁘게 해야지…. 학원은 잘된대?"
# "현우","버스도 새걸로 바꿨던데 벌써."
# "엄마 : …… 근데 연희네 학원은 왜… 문 닫았어?","현우 : 걔는 동네 꼬마들 가르쳤던 거고. 얘는 입시 학원이잖아. 엄마 : 너두 그런 데 자리 있나 한번 알아봐달라고 하지."
# "현우","어디? 학원?"
# "엄마","아니… 거기…."
# "현우 : 내가 딴따라야?","엄마 : …… 너 거기 구청 일 대충 대충 하는 거 아니지?"
# """       뭐든지 정성으루 해, 정성으루. ""","현우 : 걱정하지 마. 내가 아줌마들한테 얼마나 인기가 좋은데."
# "구청 건물 계단.","어디선가 관악기 소리들이 들린다. 종이가방을 들고 그 소리에 귀를 기울이며 걸어오는 연희. 길을 잘못 들다가 연주 소리를 따라 길을 바꿔 찾는다. 점점 연주 소리가 가까워지고… 모퉁이를 돌면 갑자기 멈추는 소리."
# "소리가 사라진 빈 복도. 관악 교습반 앞.","연희가 고개를 내밀면 현우가 아줌마들을 상대로 수업 중이다."
# "경청중인 아줌마들.","현우 : 생각해 보세요. 음악을 못 듣고 살면 이 세상이 얼마나 심심할까. 하다못해 라디오 하나가 망가져도 심심하시죠?"
# "부슬비가 내리는 거리.","연희가 현우를 기다리고 있다. ""누군가 오는 소리가 들리면 뒤를 돌아보고, 돌아보고 다시 걷고…"" 현우가 온다. 다가가 우산을 씌워 주는 연희. 현우 슬며시 피한다. 또 씌워주는 연희. 현우 가만있다."
# "연희","…."
# "현우","… 경수한테 들었니?"
# "연희","… 응. 어디 좀 들어가자. 나 추워."
# "현우 : 여기 갈 데 없어. 그냥 말해.","연희 : 오빠 왜 이런 거 해? 돈 받고 학원강사 같은 거 안하잖아."
# "현우","잠깐 하는 거야."
# """연희","선생님 어울린다, 오빠."""
# "현우","왜 왔어 ?"
# """연희","왜, 겁나? … 또 같이 살자 그럴까봐? """
# "현우","……."
# "연희","연습은 많이 했어? 좀 있으면 오디션 있잖아."
# "현우","그거 알려주러 왔어?"
# "연희","이거."
# "현우","그게 뭐야?"
# "연희","… 영양제."
# "현우","영양제?"
# "연희 : 엄마 가져다 드려.","""현우 : 우리 엄만 멀쩡하니까, 니네 엄마나 가져다 드려. 괜한 신경 쓰지 말구."" 연희 : 할머니들 다 아퍼. 이왕 가져왔는데 그냥 가져가라. 좀."
# "현우 : … 너 왜 이래?","속상한 현우는 그냥 돌아서 가 버린다."
# "라디오. DJ의 소개와 함께 흐르기 시작하는 댄스뮤직.","한두 번 정도 주파수를 바꿔보지만 댄스뮤직과 트로트가 걸린다."
# "신호등에 정차한 현우의 낡은 차.","헤드라이트가 갑자기 꺼져버린다."
# "현우","…… ?"
# "속상한 듯 차를 한대 걷어차면","헤드라이트 하나가 다시 희미하게 들어온다."
# "현우","에이 저 씨발…."
# "비 그친 동네 풍경.","마루에 걸터앉아 마당으로 난 창을 열어놓고 담배를 피우는 현우. 안쪽에서는 엄마가 사진첩을 꺼내놓고 정리를 하고 있다."
# "중간 중간 사진을 들고 쳐다보기도 하고…","""아버지 사진, 현우 학교 다닐 때 친구들과 트럼펫 들고 찍은 사진들."""
# """현우","내일 사람들이 와서 다 싸준다는데, 뭘 그렇게 싸고 또 싸고 그래? """
# "엄마 : 그게 어디… 내가 한 것만 하니.","니 방 가서 피워. 온 집안에 냄새 배게 그걸 왜 여기서 피우고 있어. 마당에 나가서 피우든지. 너 좋아 피우는 걸 왜 남한테 피해를 줘?"
# "현우","이사 갈 건데 뭐 어때?"
# "엄마 : 모기장은 왜 열어 놨어….",""" 엄마, 일어나서 현우를 밀치고 창문을 닫는다. "" 귀찮아 죽으려고 하는 현우."
# "현우","아～ 비 왔는데 무슨 모기."
# "엄마 : 어머 얘가… 이게 이게 언제 철들어.",""" 모기가 왜 없어, 있지! 요즘은 겨울에도 모기 있는 거 몰라? "" 그리구 너 모기가 비 그친 거 모를 것 같애? "" 왜… 엄마 말이 짜증나? 얹혀살지 말고 나가, 그러니까. """
# "현우 : 내가 못 나갈 거 같애?","엄마 : 그래 제발 좀 나가라… 제발. 난 너 없으면 더 좋아."
# "엄마","나가는 거니?"
# """현우","그래, 나간다."""
# "대문을 열고 나와 집을 쳐다보는 현우.","천천히 걸으며 동네를 둘러본다."
# "노란 가로등이 묻어 있는 비 웅덩이들.","색색깔 우산을 쓰고 그 웅덩이에서 물장난을 치는 아이들을"
# "엄마들이 나와 데리고 들어가고.","아직 불이 켜진 가게. 그 앞에 맥주 한잔 하는 동네 아저씨들. ""아이들도, 행인들도 집으로 돌아가고, 가게에 파라솔을 들여가는 아저씨. "" 가게 불도 꺼진다."
# "쓰레기차… 두부장사…","이제는 추워지기 시작한 날씨. 손을 불며 학교에 가는 아이들."
# """익숙한 풍경들도, 가게도, 현우네 집도, ""","점점 멀어진다."
# "“…… 엄만 이사 가니까 좋아?”","""“그럼 좋지…. 어디, 엄마두 아파트 한번 살아보자.”"""
# "현우","……."
# "S# 16. 현우네 새 집 - 저녁","아직 정리 안 된 집. 어수선하다."
# """자장면 시켜 먹은 그릇들이 현관에 쌓여 있고, ""","풀다 만 박스들이 여기 저기 놓여있다. TV 앞에 앉아 드라마를 보고 있는 현우와 짐 정리하느라 바쁜 엄마."
# """현우","여긴 테레비 잘 나온다, 엄마…. 아파트가 좋긴 좋네. """
# "현우","뭐?"
# "엄마 : 아냐… 내가 할게.","현우 : 엄마 그거 오늘 하루에 안돼… 두구두구 해야지. 내 껀 그냥 둬… 내가 할게."
# "엄마 : 니가 그러구 있으면 두구두구 해두 안되지….","‘사랑의 슬픔’ 할 때 안됐니? 그거 하면 말해. 그거 보구 정리 해야지."
# "현우 : 그건 월화 드라마라니까.","봐 엄마. 저건 일일 드라마. 매일 밤 8시 30분. ‘사랑의 슬픔’은 월요일 화요일 밤 10시. ‘안녕하세요 또 만났군요’는 수목드라마. 또…."
# """현우가 주절주절 드라마 시간대를 꿰고 있는데, ""","엄마가 뭔가를 들고서 다가온다. 발 밖에 안 보이는 엄마."
# "현우 : (짜증을 팍 내며) 내 껀 그냥 두라니까….","트럼펫을 받아서 뒤에 기대앉은 소파에 휙 던져버리는 현우."
# "적당히 정리가 된 현우 집.","밥을 먹고 있는 현우. 미역국 외 몇 개의 반찬이 놓인 식탁."
# "현우","누구 생일이야?"
# "엄마","왜? 미역국 싫으면 딴 거 끓여줄게."
# "현우","아… 씨…."
# "엄마","맛없니?"
# "현우","…… 좀 짜네."
# "엄마 : 그치 좀 짜지…?","며느리래두 있으면 더 늦기 전에 내가 음식도 가르쳐 주고 할 텐데. 늙으니까 입맛이 자꾸 짜지네……."
# "현우","……."
# "오디션장 밖 복도 의자에 앉아서 기다리는 현우.","다소 긴장한 모습이다. ""머리도 단정하게 빗고 면도도 하고, 깔끔하게 단장한 현우. 트럼펫을 들고 있다. "" 방안에서 관계자가 나와 현우의 이름을 부른다."
# "‘삑-’","긴장한 탓인지 연주 중간에 실수를 한다."
# "심사위원1","수고했어요."
# "S# 19. 국립극장 대무대 - 낮","국립극장 대극장 무대에서 시향 단원들이 공연 리허설을 하고 있다. 편한 캐주얼 차림으로 즐겁게 연습을 하는 단원들. 간혹 웃음소리도 들려온다. 공연장 입구에 서서 그들의 여유로운 연습 장면을 보는 현우."
# "현우 : (혼잣말로) 니미….","‘누구세요?’ 뒤에서 누군가 부른다. 돌아보면 수위아저씨다."
# "수위아저씨","무슨 일이세요?"
# "현우 : 아뇨. 그냥 구경 좀 하느라구요.","수위아저씨 : 여기 아무나 들어오시는 데가 아닙니다. 죄송합니다."
# "현우 : 아… 네. (억지로 웃어 보이는 현우)","연습하던 시향 단원들이 우르르 몰려나온다. 쉬는 시간인가 보다."
# "수위아저씨를 따라 나가고 있는 현우의 뒷모습.","왠지 초라해 보인다."
# "S# 20. 현우네 새 동네 - 밤","가게 앞을 지나는 현우의 전화벨이 울린다."
# "연희","…… 뭐해?"
# "현우","… 그냥 있어."
# "연희","집이야?"
# "현우","… 어."
# "연희","나… 지금 앞에 와 있는데… 잠깐 나올래?"
# "현우","어… 지금은 좀 그런데…."
# "잠시 동안 서로 말이 없는 두 사람.","현우는 가로수 옆 광고지 진열대에 기대어 쭈그려 앉은 채다."
# "연희","오빠…."
# "현우","어… 말해."
# "연희","오디션 잘 봤어?"
# "현우","어… 그거… 연기됐어. 오디션."
# "연희","……."
# "현우","……."
# "연희","나 결혼할 것 같애…"
# "현우","……."
# "연희","……."
# "현우","… 언제?"
# "연희 : … 봄에.","현우 : …… 잘됐다."
# "연희","나 미안해 해야 돼?"
# "현우 : 아니. 니가 뭐가 미안해…","야～ 너는 왜 하필 황사가 몰려오는 그런 때 결혼을 하구 그래… "" 그 얘기 할려구 그렇게 전화하구, 찾아오구, 그런 거구나? "" 말을 하지 바보야."
# "연희 : … 좋아?","현우 : 그럼 좋지… 행복해라. 제발… 부탁이다."
# "연희","진심이야?"
# "현우","…… 응."
# "연희","……."
# "현우","……."
# "연희","……그럼 끊을게. 안녕"
# "현우","……."
# "S# 22. 현우네 새 동네 -  밤","전화를 끊고 일어나 사방을 둘러보다가 새 동네로 이사 온 걸 그제서야 깨닫는 현우."
# "현우 : …….","나무를 바라보며 잠깐을 그렇게 서 있다가 무언가 결심이라도 한 듯"
# "“도계중학교”","""짧은 망설임. 전화를 꺼내면서 구멍가게로 들어가며, """
# "현우","예… 모집광고 보구 전화 드렸는데요. 예…."
# "가게 주인 옆에 김이 뿜어져 나오는 가습기.","""현우는 가습기 하얀 수증기에 얼굴을 가져 가 대보는데,"" 얼굴에 부서지는 수증기가 간지러운지 기분 좋은 표정이다."
# "연희가 중얼거리던 그 선율이 머릿속에 천천히 떠오르더니","점점 또렷해진다. ""연희의 허밍처럼 들리다가 차츰 트럼펫 선율로 분명해 지는 선율,"""
# """구청직원","누구, 찾으세요?"""
# "연희","관악부 지도 강사님 있죠…. 이현우씨."
# "구청직원","아～ 현우씨. 그만 뒀는데요?"
# "연희   : (실망한 듯) 왜요?","""구청직원: 임시직이었는데, 원래 선생님이 돌아오셔서요. """
# "연희","언제요?"
# "구청직원: 지난주에요.","""아줌마들이 강의실을 나오는데 연희가 힐끗 안을 보면,"" 배 나오고 머리 벗겨진 강사가 수업을 마치고 교단을 정리하고 있다."
# "휴게소 광장에 차도 사람도 한명 없는데","묻지 마 관광버스 한대가 들어와 멈춘다."
# """커피 한잔을 빼들고 오다가, ""","아직도 흥에 겨워 춤추는 몸짓을 하며 화장실로 걸어가는 아저씨와 마주치는 현우. 한심스럽고 기가 막히다는 표정을 짓는다."
# "S# 25. 언덕 - 낮","언덕길을 넘자 해질녘 읍내 풍경이 시야에 들어온다."
# "음료수 박스들을 이리저리 살피는 현우.","마음에 드는지 두 개를 집어들고 계산대로 간다."
# "현우 : 저… 도계중이 어느쪽이죠?","""가게주인 : 이쪽으로 쭉 가시면 삼거리가 나오거든요,"" 거기서 오른쪽으로 꺾어지면 바로 보일 거예요."
# "현우","네…"
# """현우는 음료수 박스를 들고 나와 차를 타려다, ""","수연이 나오자 길을 다시 한번 묻는다."
# "현우","저 도계중학교가 어딥니까?"
# "수연","저기 삼거리 보이시죠?"
# "차에 시동을 거는 현우.","부르르 끼릭끼릭 한참을 요동 친 후에 검은 연기를 뿜어내며 시동이 걸린다."
# "현우 : (운전을 하면서도 힐끗힐끗 쳐다본다) …","""차를 몰고 가며 주변을 둘러보다 다시 전방을 쳐다보는데,"""
# "급정거한 후 짜증스럽게 경적을 울리는 현우.","""미안하다는 듯 서둘러 길을 건너오는, 머리에 보따리를 이고 있는 할머니. "" 차 안의 현우에게 미안하다며 허리를 굽혀 인사를 계속 하신다."
# "현우","에이…씨."
# "S# 27. 학교 - 낮","""드르륵 문이 열리면, 썰렁한 교무실. 졸고 있는 당직. "" 음료수 박스를 든 현우가 들어서자 천천히 일어난다."
# "당직 : 뭐예요? 배달?","""현우 : 아니 그게 아니라요, 저… 서울에서 왔거든요. """
# "당직","네?"
# "현우","예… 저 관악부 때문에."
# "당직","예?"
# "현우 : 관악부요.","""당직 : 아～ 뺀드부? 허, 진짜 오셨네?"""
# "현우","네?"
# """당직 : 아, 아니… 이쪽으로 오세요.""","추리닝 차림으로 슬리퍼를 끌고 휘적휘적 앞서서 가는 당직 선생. 별관으로 들어서는 두 사람. 조용하다."
# "당직  : 조용한 걸 보니 애들이 다 갔나보네.",""" 전에 있던 선생이 술 쳐먹고 사고 친 담에 쫓겨 갔는데,"" 덕분에 요즘은 좀 살 것 같더니… 현우 : 네…"
# "비어있는 관악실.","아이들 주려고 사온 음료수를 들고 관악실을 둘러보는 현우."
# "제일 마지막에 걸린 사진에 눈이 가는 현우.","사람 좋게 보이는 전임교사를 중심으로 도열해 있는 관악부의 모습이 보인다."
# "사방에 갈색 커튼이 길게 드리워져 있는 관악부 연습실.","색이 바랜 각종 대회의 트로피들이 벽장을 하나 가득 메우고 있다."
# "악기와 장비들을 둘러보는 현우.","망가진 악기들이 눈에 띈다. ""낡고, 좁고, 후지고…. 매캐한 먼지. 벽에는 낙서까지…. """
# """벽을 주의 깊게 만져 보고, 바닥을 굴러도 보고, ""","군데군데 침이 그득 고인 종이컵들도 놓여있다. ""구석에 놓인, 먼지 쌓인 오래전 전국대회 우승기를 보며 신기해하는 현우. "" 한숨을 쉬며 주변을 둘러본다."
# "당직 (소리)","맘에 드세요?"
# "아무 가재도구도 가구도 없는 그냥 텅 빈 방.","TV 한 대가 바닥에 달랑 놓여 있다."
# "좀 한심한 기분이 드는 현우.","바닥을 만져보면 아직 냉기가 남아 있다."
# "이불 아래로 손을 넣어보면","엄지 손가락만한 바퀴벌레 한 마리가 이불속에서 나와 잽싸게 도망간다."
# "S# 30. 관악실 - 낮","하얗게 칠해진 별관 건물의 현관에 들어서자 시끄럽게 들려오는 연주음들. ""두두두두 경쾌한 드럼소리, 멋을 한껏 부린 색소폰 소리, """
# "계단을 지나 관악실 앞 복도에 다다른 현우.","가까워질수록 관악기 음들이 점점 커진다."
# "학생 두 명(용석이와 심벌즈)이 소리까지 질러대면서","팀파니 채와 심벌즈를 칼과 방패삼아 전투중이다. ""현우가 들어서자 두 학생, 깜짝 놀라 전투를 멈춘다."""
# "‘그대로 멈춰라’ 상태의 아이들.","호기심 어린 눈길로 현우를 바라본다. ""책상 위에 앉은 놈도 있고, 말뚝 박기 하던 놈들도 있고. "" 몇몇 아이들은 안대를 하고 있다."
# "심벌즈","누구세요? 저… 여기 아무나 들어오면 안 되는데요!"
# "현우","……."
# "심벌즈 : (단호하게) 들어오시면 안 되는데요!","현우 : 어… 여기가 뺀드부 맞지?"
# "심벌즈","뺀드부가 아니라 관악분데요."
# "현우 : 어 그래… 관악부.","문이 열리며 당직이 따라 들어온다. 당직을 보는 아이들의 재수 없다는 표정을 금방 읽어내는 현우."
# """악장이 일어나 “차렷, 경례”를 시킨다.""","무슨 말을 하려다가 자세를 잡고 거만하게 인사를 받는 당직."
# """당직","어 그래, 이 선생님은 여러분을 앞으로 지도해 주실 """
# "악장","선생님 서울에서 오셨어요?"
# "현우","응."
# "아이들","……."
# "용석","서울대학교 나오셨어요?"
# "현우","응?… 응…."
# "대답이 없는 아이들.","현우 : 니네들은 다 눈병 걸린 거야?"
# "심벌즈","예."
# "재미있어 하는 현우.","현우 : 저거 니네가 가져온 거니?"
# "아이들","… 네."
# "현우 : 작년 게 아니던데? 니네가 가져온 거 아니지?","악장 : …… 저희 선배들이 가져온 거예요. 몇 년 전에."
# "심벌즈","올해는 우리도 우승할 건데요?"
# "현우","……."
# """현우","넌, 음악 왜 하니?"""
# "악장","네?!"
# """현우","음악, 왜 하냐구…. """
# "악장","…… 저기… 그게 저…."
# "안대를 한 재일이와 현우.","재일이의 작은 손에 들려있는 트럼펫에는 구멍도 나 있다."
# "현우","트럼펫이야?"
# "재일 : 네…. 근데 저… 주무실 데는 있으세요?","현우 : 어..? 어…. 근데 그거 소리 나는 거니? 줘 봐."
# "재일","잘 안나요."
# """현우","야, 좀… 떨어져. """
# "---경과 --","""색소폰을 들고 선 용석. 바지를 바싹 줄여 입은데다, "" 염색이라도 했는지 머리카락엔 갈색 빛이 돈다."
# "용석","……."
# "현우","한번 불어봐. 뭐 잘하나 보자!"
# "용석","……."
# "현우 : 그냥 아무거나 해 봐.","연주하는 용석이. 나름대로 제 소리를 찾아가는 용석의 연주. 약간의 기교도 부릴 줄 안다."
# "현우","됐어. 그만."
# "용석","……."
# "현우","곧잘 하네."
# "용석","……."
# """현우","넌 왜 음악하니? 이거, 관악부 왜 해?"""
# "용석","……."
# "현우","말해봐."
# "용석","유명해질 거예요."
# "현우","유명한 사람… 아는 사람 있어?"
# "용석","케니 지요."
# """현우","오, 케니 지?"""
# "엉거주춤 일어나 나가려는 용석에게","현우 : 폼 잡지 마. 알았어? 음악은 폼으로 하는 게 아니야."
# "용석","……."
# "복도에는 자기 차례를 기다리는 무료한 아이들.","밖을 보며 창가에 기대어 있다. 잠시 후 기분 나쁜 표정의 용석이 나온다."
# "심벌즈는 엉뚱한 박자에 쳐 버리고.","""팀파니, 플룻, 트럼본… 짧게 짧게 제 역할을 하고 빠지는 그림들."""
# "안쪽에 방이 하나 있을 만한 아담한 시골 읍내 약국.","약국 오디오에서 귀에 익숙한 음악이 흘러나온다."
# "추리닝 차림으로 약국 안으로 들어서는 현우.","사람을 찾는데 보이지 않는다."
# "약국 안으로 들어온다. 손에 들린 떡 봉지.","현우 : 사람이 없나 본데요?"
# "수연 : 그래요? 장사 안하나?","""현우, 시끄러운지 진열대 너머의 오디오를 눌러 끄더니 "" 방문 앞에 서서 사람을 부르다가 그 안을 들여다본다."
# """수연","뭐하세요, 지금?"""
# "현우","예? 주인 찾는데요?"
# "현우","……."
# "수연 : …….","""현우 : 속이 좀 안 좋아서 그러는데, 소화제 좀 주세요. "" 수연 : 참 나…. 속이 어떻게 안 좋으신데요? ""현우 : 그냥 더부룩 하구, 자꾸 헛트름 나오구, 좀 아파요. 가끔 가다…."""
# "수연","……. 잘 때두 아프세요?"
# "현우","네. 자다가도 아파서 깨요."
# "수연","변비두 심하구요?"
# "현우 : ……… 있어요.","수연 : 속이 많이 상하신 것 같거든요? 병원에 먼저 가보세요."
# "현우","아녜요… 저는 그냥 소화제 먹으면 낫더라구요."
# "수연","……."
# "현우","그냥 소화제나 좋은 거 하나 주세요."
# "더 이상 관심 없다는 듯 서랍에서 약을 꺼내는 수연.","몸을 굽히면 가운 속으로 하얀 속살이 조금 내보인다."
# """슬쩍 들여다보는 현우, ""","수연 : 식사하시구요 30분 있다 드세요."
# "현우 : 예.","수연 : 2500원입니다."
# """현우 : 참, 혹시 눈병 예방약 같은 거 있어요?""","수연 : 그런 건 없어요…. 소화제 드시면 눈병 안 걸려요."
# "S# 33. 기찻길 옆 - 낮","""약국을 나온 현우, 좌판들이 있는 길 건너편으로 다가온다."" ""떡 파는 할머니 앞, 색색깔의 예쁜 떡들에 눈길을 주는 현우."""
# "할머니 : 떡 들여가요.","""현우가 쭈그리고 앉자, 할머니가 인절미를 하나 집어 입에 넣어준다."""
# "할머니","맛있지?"
# """당황스럽다. 서둘러 자리를 뜨려는 듯,""","현우 : 이거 한 봉지 주세요. 얼마예요?"
# "할머니","이천원."
# """현우, 주머니를 뒤져보는데, 동전 몇 개뿐이다.""","할머니 : 없으면 그냥 다음에 줘도 돼."
# "현우 : 아… 아니예요….","할머니 : 가져가서 맛있게 먹어요."
# "떡봉지를 하나 들고 건널목에 서 있는 현우.","연희가 흥얼거리던 곡을 흥얼거리고 있다."
# "바람을 일으키며 현우 앞을 쏜살같이 지나치는 화물열차.","현우의 흥얼거림이 열차소리에 묻힌다."
# "빈 복도.","""아이들의 불협화음 연주 소리가 들려오다가 갑자기 뚝 그치면, "" 두루마리 휴지를 든 심벌즈가 튀어나온다."
# "현우 : 화장실 갈 사람들 갔다 와.","아이들 일어나서 나간다."
# "현우의 전화가 울린다. 확인하고 받지 않는 현우.","전화 계속 울린다. 전화를 받지 않는 현우를 아이들이 이상하게 쳐다본다."
# "용석","전화 왔는데요?"
# "현우","……."
# "현우","여보세요?"
# "남자","예… 안녕하세요. 이현우 고객님이시죠?"
# "현우","그런데요."
# """남자 : 예, 여기 “쓰자 카드”인데요. ""","고객님 카드 값이 석달째 연체되고 있어서 전화 드렸습니다."
# """현우 : 나, 돈 쓴 거 없는데….""","남자 : “티파니 3종세트” 라고 되어있는데요. 2001년 연말에 구입하셨네요."
# "현우","티파니요?"
# "남자","귀금속류 취급하는 곳 아닌가요?"
# "현우","……."
# "남자","다음 주까지 되시겠습니까?"
# """현우","예…. 아니, 월말까지 넣을게요. """
# "길가를 둘러보며 걷고 있던 현우.","휴대폰을 꺼내 전화를 건다."
# "현우","안녕하세요-"
# """경수","왜 전화했냐, 너? """
# "현우","새끼 삐지긴."
# "경수 : 너 강원도 가서 선생님 한다며? 좋냐?","""현우 : 조ㅤㅇㅗㅎ지. 애들 착하지, 공기 좋지, 여기 또 이쁜 약사언니도 있어요…. """
# "경수","애들은 잘해?"
# """현우 : 어, 다 너만큼은 하던데?""","경수 : 아니다 싶으면 때려치든가…. 현우 : 봄에 애들 무슨 대회가 있댄다. 그때까진 있어야 돼. 서울 가면 또 내가 뭐하냐. 누가 날 반겨준다구…"
# """경수","나 있잖아, 나."""
# "<파라다이스 캬바레 뺀드 연주자 모집. 숙식 제공>","현우 : 너 밤무대는 계속 다니냐? 경수 : 밤무대가 뭐냐 밤무대가…. 다니지 그럼. 그게 돈이 얼만데. 현우 : 어이구 좋겠다."
# "경수","너… 연희 결혼한다는 얘기 들었어?"
# "현우","…… 아니?"
# "경수","몰랐어?"
# "현우","응…. 잘됐네."
# "경수","…… 괜찮아?"
# "현우","그럼 괜찮지."
# "S# 36. 학교 옆 도로 - 낮","수정이가 앞서가고 용석이가 뒤를 따른다."
# "약간 주눅이 든 듯 뒤를 계속 따라가는 용석이","둘이서 티격태격 하더니 도서관 쪽으로 수정이가 가 버린다. ""터벅터벅 걸어오는 용석이가 고개를 들면, 차를 세우고 보고 있는 현우."""
# "현우","그래가지구 여자 꼬시겠어?"
# "용석","……."
# "현우","좋아해?"
# "용석","……."
# "현우","왜 대답이 없어."
# "용석","절 별루 안 좋아해요."
# "현우","내가 볼 땐 너 많이 좋아하는 거 같은데?"
# "용석 : … 아니에요.","현우 : 너 나팔 잘 불잖아. 나팔도 불어주구 그래야지. 그래야 좋아하지. 따라만 다닌다구 되니? 폼 잘 잡구 불어야 된다. 알았지?"
# "용석","……."
# "현우","잘해봐."
# "용석","……."
# "현우","야. 너 이름 뭐지?"
# "용석","강용석인데요."
# """현우","어 그래. 용석아, 너 밥 먹었어?"""
# "용석","먹었는데요…. 왜요?"
# "현우","아냐…."
# "재일이 아르바이트 하고 있는 동네 어귀의 주유소.","“이 차에는 아가씨가 타고 있습니다” 라고 쓰인 티코가 서 있다."
# "트럭에 주유를 끝내고 사무실로 들어오는 재일.","사무실 안에는 사장이 커피를 시켜놓고 레지와 히히덕거리고 있다"
# "재일","저 갈게요."
# "사장","내일은 늦지 마라."
# "재일이 사무실 문을 막 나서는데","주유소 옆에 딸린 카센터로 현우의 차가 달달달 들어온다. 빵빵- 경적을 울리자 안쪽에서 밥 먹다 말고 나오는 남자. ""인상은 조금 걸걸한데, 눈은 선하게 생겼다. 주호다."""
# """현우","어, 너 여기서 아르바이트 하는구나."""
# "재일","안녕하세요?"
# "현우 : (주호보고) 이게 시동이 잘 안 걸리네요.","주호 : 네… 본넷 좀 열어 주세요."
# "재일","새로 오신 관악부 선생님이예요."
# "주호","우리 재일이 좀 잘 봐주세요."
# "현우","네…. 식사 중이신데 괜히…."
# "주호","다 먹었어요."
# "S# 38. 파출소 앞 - 밤","낡은 현우 차에 어울리지 않는 고급스러운 오디오를 보고는 궁금해 하는 재일이. 오디오에 반쯤 나와 있는 테입을 밀어 넣는다."
# "재일","이거 제목이 뭐예요?"
# "현우 : 제목? 제목 없는데…?","""재일 : 왜요? 선생님이 만드신 거예요? """
# "현우 : 어… 옛날에 뭐… 재미로 만든 거야 대충….","재일 : 되게 좋다."
# "현우","좋긴 뭐가 좋아. 우울하기만 하지."
# "재일 : 좋은데….","파출소 앞을 지나는데 안에서 할머니가 나오는 것이 보인다."
# "재일","어! 잠깐만요."
# "연신 ‘죄송합니다’ 하며 머리를 조아리는 할머니.","""현우 : 어? 왜, 아는 할머니야?"""
# "재일","네…. 그냥 가세요."
# "현우","왜? 태워드리지…."
# """재일","아니요, 그냥 가세요."""
# "이상하다는 표정을 지으며 출발하려는데","할머니는 신호등을 무시하고 그냥 길을 건너간다. 위태로워 보이는 할머니."
# """재일이는 할머니가 볼까 고개를 수그리고 있고, ""","현우는 할머니가 길을 건너는 동안 기다린다."
# "현우","좀 기다려라 임마."
# "재일 : 예?","""현우 : 어, 아냐, 너 말고…. 근데, 할머니가 왜 파출소에서 나오시니?"""
# "재일이","……."
# "현우","…… 밥 먹었어?"
# "재일 : 아뇨.","""현우 : 잘됐다… 나 밥 혼자 먹기 싫은데, 선생님이랑 같이 먹을래? """
# "재일 : (라면을 보더니) 밥은 없어요?","현우 : 맨날 먹는 밥 또 먹어? 라면 맛있잖아. 가끔 라면도 먹어줘야지."
# "재일","저… 아까 그 곡은 악보 없어요?"
# "현우 : (힐끗 보고는) 지금은 없는데… 왜?","""재일 : 연습해서요, 우리 할머니 좀 불어드리게요. "" 현우 : 그래 그럼…. 내가 나중에 그려줄게."
# "재일","네."
# "재일 : 김치는 없어요?","현우 : 그냥 먹자. 라면은 김치 없이 먹는 게 더 맛있는 거야 원래."
# "재일","그래두…."
# "현우 : 니가 아직 배가 덜 고프구나?","재일 : …… 선생님. 근데 우리 정말 우승 할 수 있을까요? 현우 : 내가 니네한테 우승할 수 있다고 하면 그건 사기치는 거야. 그럴 순 없잖아. 재일 : … 근데 이번에두 상 못타면 관악부 없어질지도 모른대요."
# "현우 : 그래? 학교가 뭐 그래?","재일 : 애들이 선생님 서울에서 왔다구 굉장히 좋아하는데."
# "현우","서울서 온 선생님은 뭐 다르니?"
# "재일","그래두 선생님은 서울대학교 나오셨잖아요."
# "움찔 하고는 라면만 먹는 현우.","김치를 집으려 손이 가는데 김치가 없다."
# "젓가락을 놓더니","현우 : … 이거 김치 없으니까 정말 못 먹겠다."
# "재일","선생님 악기는 어디 있어요? 좀 보여주세요."
# "현우 : 응?","주위를 둘러봐도 현우의 은색 트럼펫이 보이지 않는다."
# "S# 40. 약국 앞 - 밤","현우와 재일이 함께 걸어가다가 약국 셔터를 내리고 있는 수연을 본다."
# """수연","어, 재일이구나?"""
# "재일","우리 선생님이에요."
# """수연","… 어, 그래?"""
# "현우","도와드릴까요?"
# "쇠꼬챙이로 셔터를 끌어내리는 수연을 도와주는 현우.","사실 누가 도와주지 않아도 그녀에게는 너무나 익숙한 일이다. 뭔가 어색한 기분의 현우. 수연이 내려놓은 비닐봉투를 들어 준다."
# "수연","감사합니다."
# "현우","문을 일찍 닫으시네요."
# """수연","…… 아, 그거."""
# "현우","저기…"
# "수연","속은 괜찮으세요?"
# "현우","예."
# "수연","재일인 집에 가니?"
# "재일","네."
# """수연","그래, 그럼 누나 좀 집에 바래다줄래?"""
# "재일","네."
# "현우","어 그래…. 잘 가라!"
# "S# 41. 관악실 - 낮","""교장, 당직 , 몇 명의 교사들이 연습실 뒤쪽에 쭉 늘어서서 "" 관악부 아이들의 연주를 보고 있다. 잔뜩 긴장해서 연주를 하는 아이들. 실수투성이다. 왠지 검사를 받는 느낌도 들고 현우의 기분도 언짢다."
# "연주가 끝난 후 실망스러운 표정의 교장.","당직과 다른 교사들은 내심 잘됐다 싶은 표정이다."
# "당직","대회나 나갈 수 있을지 모르겠네."
# "현우","……."
# "당직 : 기왕 시작한거니 잘 좀 지도해보세요.","봄까지 애들 실력이 많이 안 늘면 대회는 포기해야지 뭐."
# "현우","예…."
# "나가는 교장과 교사들.","의기소침해져서 고개를 푹 숙이고 현우만 바라보는 아이들. ""휴지를 들고 들어오던 심벌즈, 분위기가 안좋자 조심조심 자리로 들어간다."""
# "현우","표정들이 왜 그래 ? 걱정하지 마."
# "아이들 : …….","""현우 : 니네 음악이 좋아서 시작했지, 대회 나가고 상 탈려고 시작했어?"" 다른 거 뭘 바라고 음악하면 안돼."
# "여전히 실망한 채인 아이들의 표정.","""현우 : 악장, 악보 모아둔 것들 있니?"""
# "악장","네."
# "현우 : 가져와봐.","악장이 자기 악보집을 건넨다."
# "현우","이거 말고 총보 없어?"
# "S# 42. 건널목 - 낮 (비)","읍내에 비가 내리기 시작한다."
# "악보뭉치를 머리 위에 얹고 뛰어서 건널목을 건너는데","재일이 할머니가 남의 가게 처마 밑에 앉아서 도시락을 먹고 있다."
# "현우","무슨 비가 이렇게 와. 겨울에…."
# "수연이 없자 나가려는 현우.","문을 열고 나가지만 비가 너무 많이 온다."
# """다시 들어오는 현우, ""","빗소리에 묻힌 약국 안에 음악소리가 낮게 들린다."
# "의자에 앉아 창밖을 보며 노래를 듣는 현우.","연희가 부르던 음악과 오버랩 된다."
# "눈을 감는 현우.","빗소리와 함께 머릿속에 떠오르는 선율… 점점 더 분명해진다."
# "수연 (소리)","오셨어요?"
# "잠든 현우 얼굴을 가만히 보고 있는 수연.","눈을 뜨는 현우. 얼굴을 조금 돌린다."
# """현우","아, 네…. 비가 하두 와서… 좀 있다 가려구…. """
# "수연","비요?"
# "현우 : 네…. 밖에….","돌아보면 창 밖은 온통 눈 세상이다."
# "펑펑 퍼붓고 있는 함박눈.","""사람들 즐겁게 눈을 맞으며 다니고, 수연도 눈을 털어내고 있다. """
# "현우 : 어? 아까 비 왔는데….","수연 : 무슨 비가 와요. 아까부터 하루 종일 눈이 왔는데…."
# """현우, 멍하게 창 밖만 본다.""","수연 : 여기는 겨울이 일찍 와요. 눈두 엄청 오구요. 눈 좋아하세요?"
# "현우","……."
# "그런 현우를 바라보는 수연.","현우의 시선이 닿는 곳에 재일이 할머니가 눈을 맞으며 위태롭게 걸어간다."
# "현우가 앉은뱅이책상에 앉아","악장에게 받은 총보를 꺼내놓고 대충 훑어보고 있다."
# """눈으로 대강 대강 보는데, ""","눈으로 지나가는 음표들이 마음속에 연주된다."
# "처음엔 희미하게 들리던 선율이…","짧고 선명하게 이어진다."
# "물에 젖어 엉켜있는 음표들.","소리도 따라서 엉킨다."
# "짜증이 나는지 악보를 치우는 현우.","엉켰던 불협화음들도 따라서 멈춘다."
# "하얗게 눈이 내린 도계의 풍경.","현우와 심벌즈가 어디론가 가고 있다."
# "현우","아직 멀었냐?"
# "심벌즈","……."
# "골목에 줄지어 선 광산 사택들.","동네가 좀 을씨년스럽다."
# "심벌즈","여긴데요."
# "빛이 들어오지 않아 어두운 집안.","희미한 빛만이 어디가 방이고 어디가 부엌인지 가늠하게 해준다."
# "현우","스위치가… 어딨냐?"
# "심벌즈","재일아…. 재일아…!"
# "스위치를 올려도 불이 들어오지 않는 재일이 집.","""라이타를 켜고 둘러보면, 재일이 것으로 보이는 앉은뱅이책상 위에 초가 놓여져 있다."""
# "초에 불을 붙이는 현우.","초라한 방의 모양새가 희미하게 드러난다. 라면 먹다 그대로 둔 그릇들. 부엌에 쌓여 있는 라면 박스들."
# "현우","……."
# "병실 안을 들여다보는 현우와 심벌즈.","""한쪽 침대에 할머니가 잠들어 있고, 재일이는 만화책을 보고 있다. "" 심벌즈가 들어가 재일이를 불러낸다."
# "현우","언제 이러셨니?"
# "재일","눈 많이 오던 날이요. 눈에 미끄러져서."
# "현우","… 밥은 먹었어?"
# "재일","네. 간호사 누나가 줬어요."
# "현우","……. 너무 걱정 마. 금방 나으실 거야."
# "재일","네."
# "현우","…… 연습 많이 했어?"
# "재일 : (쑥스럽게) 아뇨.","카센터의 주호가 어느 노인을 부축해 복도를 가로지른다."
# "지나가며 현우와 가벼운 눈인사를 나누는 주호.","재일이도 심벌즈도 인사를 한다."
# "창구직원","보호자세요?"
# "현우 : 네….","창구직원 : 아직 퇴원을 못하시거든요. 입원비가 지불이 안돼서…."
# "병원을 나서는 현우와 심벌즈.","말없이 걷는다."
# "현우","불 좀 있냐?"
# "심벌즈","……."
# "선물을 안 주신대요”","""저 멀리 캬바레 입구에 세워져있는 조잡한 크리스마스트리에선 불빛들이 반짝이고,"" 그 옆 모니터에선 캐롤도 들려온다."
# "현우","이런… 나 욕해두 되냐?"
# "심벌즈","… 하세요."
# "현우 : (담배연기만) 후….","""담배 연기를 뿜는 현우의 눈에 들어오는, 전에 보았던 캬바레 구인광고."""
# "손님이 몇 없는 아직 한산한 캬바레.","한쪽 탁자에 사장으로 보이는 남자와 현우가 마주 앉아있다."
# "그곳의 모든 분위기가 몹시 어색한 현우.","사장 : 아니 뭐… 돈을 미리 땡기는 건 문제가 아닌데…. 이런 데 경험도 없다면서. 내가 실력을 봐야 뭘 결정을 하지…."
# "현우","……."
# """사장","야, 일루와 봐."""
# "--사이--","알록달록 반짝반짝 무대의상을 입고 무대 한쪽에 올라가 색소폰을 드는 현우. 뒤의 밴드와 몇 마디 나누고는 조심스럽게 연주를 시작한다."
# """처음에 낯설어하던 손님들도 어느새 음악에 빠져들고,""","미심쩍은 표정으로 지켜보던 사장의 얼굴도 만족스런 미소로 바뀐다."
# "S# 49. 재일이 집 - 밤","불이 환하게 켜진다."
# """재일이가 할머니를 모시고 들어오고, ""","""밀가루며 쌀푸대를 용석이와 심벌즈, 악장이 날라다 구석에 쌓아놓는다."""
# "문밖까지 배웅을 나온 주일이.","돌아가는 현우도 발걸음이 가볍다."
# "약국 안을 기웃거리는 현우.","웬 젊은 남자 하나가 수연 앞에서 서성대고 있다."
# "어색하게 무슨 말인가 자꾸 거는 듯하지만","수연은 별 대꾸가 없이 난처한 표정만 짓는다."
# "두 사람의 분위기가 왠지 이상하다고 느끼는 현우.","젊은 남자가 수연에게 수작을 부리는 듯하다."
# "현우","안녕하세요?"
# "수연","예… 안녕하세요."
# "어색하게 엇갈려 지나가는 현우와 주호.","수연의 표정이 이상하다. 눈이 부은 것 같기도 하고 얼굴이 몹시 어둡다."
# "현우","… 아는 분이에요?"
# "수연 : 예….","현우 : 나두 한번 봤어요. 카센터에서. 사람 참 서글서글하던데…."
# "수연","이 동네에서 유명한 깡패예요."
# "현우","그래요? 왜? 뭐? 돈 뜯으러 온 거예요?"
# "수연","아뇨…. 그런 거 아니에요."
# "현우","조심하세요. 괜히 혼자 있다가 큰일 나지."
# "씩 웃기만 하는 수연.","현우 : 남자들 조심해야 돼요. 아저씨들도 마찬가지고…. 수연 : 뭐 필요한 거 있으세요?"
# "현우","아… 소화제 좀 주세요."
# "수연 : 저번에 사가신 거 벌써 다 드셨어요?","""현우 : 예? 아, 예… 맨날 맛없는 거 먹으니까 속이 안 낫네. "" 수연 : 밥을 해 드세요. 때 맞춰서. 안 그럼 그거 약두 없어요. "" ……. 제가 잘 아는 맛있는 집 있는데, 가실래요? """
# "현우 : ….","""수연 : 저는 소개만 하구요, 선생님이 사시는 거예요. """
# "창밖의 바다를 바라보고 있는 현우와 수연.","허름하긴 하지만 음식 맛은 꽤 좋을 것 같아 보이는 집이다."
# """테이블 위에는 몸통은 온통 회를 쳐놨지만, ""","""아직 살아서 이리저리 눈을 굴리고 있는 생선이 접시에 놓여있고, "" 몸통의 한 반쯤은 이미 두 사람의 뱃속으로 들어가고 없다."
# "수연 : 술 너무 많이 드시는 거 아녜요 ?","""현우 : …… 난 있잖아요…. 전 남편, 헤어진 옛 남자 친구, 그런 말들이 좋아요. """
# "수연","왜요?"
# "현우","…… 내가 악당이잖아요."
# "수연","……."
# "현우","……."
# "수연","…… 악당노릇하기 어때요?"
# "현우","원래 악당이 더 아픈 거예요. 악당이니까."
# """       현우, 수연을 잠시 바라보는데,""","수연이 입 모양으로만 “왜요?” 하며 앞으로 고개를 살짝 숙여 다가온다. 그 모습이 굉장히 귀엽다."
# "현우","여기 자주 와야겠네."
# "S# 52. 바닷가 언덕 - 흐린 오후","겨울 바닷가가 보이는 언덕에 차가 세워져 있다."
# "그 근처가 아베크족들이 모이는 곳인 듯.","군데군데 언덕에 주차된 차들. 그 옆에는 바다찌꺼기가 달라붙은 팻말."
# """차 안에 앉아 바다를 보던 현우가 수연을 보면,  ""","""수연은 조금 떨어진 커피 자판기 앞에 서서 동전을 찾는데, """
# "수연","100원이 모자라네요…."
# "현우","수연씨는 옛날에 좋아했던 사람 없어요?"
# "수연","왜 없겠어요."
# "현우","많이 좋아했어요?"
# "수연","……."
# "현우 : …….","""창밖을 바라보던 수연을 쳐다보던 현우. 속으로 뭔가 생각하는 듯 하다가,"" 다시 앞으로 시선을 돌리며 의자를 뒤로 젖힌다."
# "현우","조금만 더 있다가 가요."
# "그러다 사이드 브레이크를 건드렸는지","완만하게 경사진 언덕에 서 있던 차가 슬슬 앞으로 가더니 앞차를 쿵 받아버린다."
# "수연","어머…."
# "앞차에서 나오는 남자. 자기 차 뒤를 확인하더니","현우 창 쪽으로 와서 삐딱하게 선다."
# "남자","… 아저씨."
# "왜 이래요? 에? 나 오늘 기분도 좆같은데….","현우 : 죄송합니다."
# "여자 : 오빠 그냥 와아!","남자는 그 여자를 한번 돌아보고 다시 현우와 수연을 바라보더니 다 귀찮은 듯 손으로 됐다는 표현을 하고는 자기 차로 돌아간다."
# """S# 53. 수연 집 앞, 언덕 - 해질녘""","언덕 아래에 서있는 현우의 차. 언덕을 걸어 오르는 두 사람."
# "현우","집이 여기 위예요?"
# "수연 : 네….","언덕을 오르는데 색소폰 소리가 들린다."
# "성당이 내려다보이는 그 곳.","""경사진 길을 따라 언덕에 거의 올라왔을 때 눈앞에 보이는 것은,"""
# "그 모습을 바라보고 있는 수정이.","용석이 연주하는 것은 수연의 약국에서 몇 번 들었던 그 음악이다."
# """그제야 알아 챈 용석이, 연주를 멈추고 굳어버린다.""","현우 : 연습 잘 되냐? 폼 잘 잡았어?"
# "현우","괜찮아."
# "용석","……."
# "수정","야… 가자…."
# "현우","갈래?"
# "용석","……."
# "수정","안녕히 계세요."
# "현우","저 곡 좋아하죠?"
# "수연","……."
# "현우","약국가면 맨날 저거 듣길래…."
# "수연","부럽다…. 선생님도 저런 적 있으시죠?"
# "현우","나중에요…. 나팔을 서울에 두고 왔어요."
# "수연","…… 해 본 소리예요. 조심해 들어가세요."
# "현우","그럼 갈게요."
# """수연","어, 잠깐만요. """
# "수연","아까 못 먹은 거. 여긴 100원 싸거든요."
# "현우","…."
# "수연","어때요?"
# "현우","오늘은 맛있네요."
# "수연","?"
# "오렌지 빛으로 저무는 도계의 하루.","읍내의 가로등이 하나 둘씩 들어오기 시작한다."
# "S# 54. 관악실 - 낮","현우가 문을 열고 들어오자 온갖 냄새가 진동을 한다."
# "현우","어휴 냄새…. 창문 좀 열어라!"
# "아이들 일어나 창문을 열고.","""그제서야 둘러보면, 바닥에 두런두런 앉아 도시락을 먹고 있는 아이들. """
# "현우","용석인 어디 갔어? 땡땡이 친 거야?"
# "S# 55. 거리 - 밤","""크리스마스 이브, 밤늦은 거리. 화려하진 않지만 제법 들뜬 분위기."" 바싹 줄여 입은 바지에 머리엔 무스를 잔뜩 바른 용석이가 수정이와 수다를 떨며 지나고 있다."
# """수정 : 용석아, 너도 저렇게 불 줄 알어?""","""용석 : 당근이지. 저런 건 누워서도 분다, 씨…. """
# """수정","어… 저 사람, 그때 그 선생님 아냐? """
# """용석 : … 수정아, 너 먼저 가라.""",""" 용석, 서둘러 캬바레 입구 계단으로 들어서서 둘러보다가 "" 십대후반의 웨이터를 발견한다."
# "용석","형! 형!"
# """크리스마스를 알리는 장식들, 현수막.""","""무대 위 현우에게 시선을 고정한 채, 원빈의 안내를 받으며"" 술 마시고 춤추는 사람들 사이를 지나 한쪽 구석에 자리를 잡는 용석."
# """꽤 진지한 모습으로 연주에 몰입하고 있는 현우,""","현란한 조명 받으며 이어지는 현우의 연주에 용석이는 넋을 잃을 지경이다."
# """연주가 끝나고 객석을 향해 인사하던 현우, ""","한쪽 구석의 용석을 발견한다."
# "묘한 표정의 용석을 앉혀놓고 분위기를 잡고 있는 현우.","용석 : 돈 때문에 음악하면 안된다고 했잖아요. 선생님이 이런 데서 뭐하세요? ""현우 : 용석아…. 내가 이걸 하는 거는, 그러니까, "" "" 선생님도 원래 이런 걸 안 좋아해… 근데, 그게…"""
# "용석","……."
# """현우","너 임마, 어제 왜 연습 빠졌어?"""
# """농협으로 들어가는 현우, ""","""추워서 밖에 안나가고 현관 안에서 누군가를 기다리는 사람들,"""
# """현우, 현금지급기 앞에 서서 카드를 넣고""","잠시 멈추었다가… 비밀번호를 누른다."
# "현금지급기에서 돈을 세는 소리가 들리고….","돈을 들고 바라보는 현우. 만원짜리 뭉치가 두둑하다."
# "라면을 끓여가지고 문지방을 넘어 들어오는 현우.","뜨거워서 호들갑을 떤다."
# "한쪽 벽에 기대고 앉아 라면을 먹는 현우.","TV에서는 불우이웃돕기 특집 프로그램이 진행 중이다."
# """그릇을 한쪽 손에 들고 국수를 먹는 자세가, ""","TV 뒤 거울에 비친 현우 자신의 모습과 정확히 똑같다."
# "입에 넣으려던 라면가락을 다시 내려놓는 현우.","자기 신세가 한심스럽다."
# """현우","어, 엄마. """
# "엄마","너는 전화두 없니?"
# "현우","어… 일이 계속 있어서 시간이 잘 안 나네…."
# "엄마 : 떡국도 못먹구….","""현우 : 잘 먹어요. 떡국, 맛두 없는 거 먹어서 뭐해."" 엄마두 집에 있지만 말구 노인정두 가구 그래.."
# "엄마","ㄴㅇㄹㅇ… 나ㅓ롸ㅓㄴㅇ…."
# "현우","여보세요?"
# "엄마 : ㄴㅇ…ㅓ로… 녈고….","""현우 : 엄마… 엄마… 안 들려? 끊어. 다시 걸게, 내가…. """
# "다시 거는 현우.","신호가 가는데 한참을 안받는다."
# "현우","왜 이렇게 안 받어?"
# "상대방","……."
# "현우","…… 여보세요."
# "연희","왜 걸었어?"
# "현우","……."
# "연희 : …… 오빠 (왜 대답 안하냐는)","현우 : 어…. 생일 축하한다. 뭐 선물 좋은 거 많이 받았냐?"
# "연희","그거 궁금해서 걸었어?"
# "현우","…… 준비는 잘 돼가니?"
# "연희","응…."
# "현우","그래…. 잘됐다…."
# "창밖을 보는 현우.","눈발이 조금 날리기 시작한다."
# "현우","…… 연희야."
# "연희","…… 응?"
# "현우","행복해라… 꼭…."
# "연희","… 오빠…. 무슨 일 있어?"
# "현우","아니. 일은 무슨 일…."
# "연희","… 오빠 지방 내려가 있다면서?"
# "현우","그렇게 됐어."
# "연희","밥은 잘 먹어?"
# "현우","그럼."
# "연희","누구랑 먹을 사람은 있어?"
# "현우","응… 아까 애들 와서 같이 먹었어…."
# "연희","애들?"
# "현우","응. 나 여기서 애들 가르쳐."
# "연희","그래? 잘됐네…. 좋다…."
# "현우","… 연희야… 새해 복 많이 받아라."
# "연희","… 오빠두 새해 복 많이 받어."
# "현우","… 응. 그래 끊자."
# "연희","알았어…."
# "현우","… 먼저 끊어."
# "연희","… 응."
# "현우집 앞 가로등 밑으로 떨어지기 시작하는 눈송이들.","트럼펫으로 연주되는 “올드 랭 사인”이 어디선가 들려온다."
# "S# 61. 재일이 집 - 아침","""조그만 밥상 주위에 현우, 재일이, 재일이 할머니가 둘러앉았다."" ""국자를 들고, 가운데 올려진 누런 냄비에서 한 그릇씩 떡국을 뜨고 있는 재일이."""
# "반찬은 김치 하나.","""부실한 모양새, 하지만 왠지 맛있어 보이는 떡국에선 김이 모락모락 피어오르고 있다."""
# """현우 : 우와～ 아니, 몸도 안 좋으신데….""","할머니 : 많이 드세요. 선생님. 딴 거 뭘 못 넣어서. ""현우 : 딴 거 뭘 넣어요, 넣긴. 할머니 떡이 최고죠. "" 저희두 집에서 이렇게 먹어요."
# """재일이 집을 나서는 현우, 재일이가 뒤따라 나온다.""","현우 : 이거…. 그때 그 곡 악보."
# """재일","아, 고맙습니다…."""
# "현우","너한테 맞게 좀 고쳤어."
# "재일","네?"
# "현우","이 곡이 원래 성인용이었거든…."
# "재일","네…."
# """현우 : 재일아, 너 나한테 세배 좀 해봐라!""","재일 : 네? 새해 복 많이 받으세요! 현우 : 자… 세뱃돈 줘야지. 올해에는 연습 더 열심히 해라."
# """현우, 메고 있던 불룩한 가방 안에서""","차에 있던 테입과 만원짜리 한 장을 꺼내 재일이에게 건넨다."
# "난간에 앉아서 기다리는 현우.","수연이 옆에 와서 앉는다."
# "수연","어디 가죠? 여긴 갈 데도 없는데."
# "현우","그냥 좀 걷죠 뭐. 약국은요 ?"
# "수연","새해 첫날 문 여는 약국이 어딨어요."
# "현우 : 그래두 아픈 사람 있을 텐데….","수연 : 아픈 사람 여기 있잖아요.."
# "현우","……."
# "수연","누구랑 점심은 드셨어요?"
# "현우","…… 여자들은 왜 그런 걸 물어봐요?"
# "수연","누가 또 그런 거 물어봤나보죠?"
# "현우 : (미소) ….","멀리 기차 역사에 불이 들어온다."
# "현우","기차 타본지도 오래됐네…."
# "수연","……."
# "하얀 눈밭을 지나는 기차.","창 밖을 스쳐가는 것들을 바라보면 천천히 떠오르는 선율."
# "가볍게 고개를 흔들어 보는 현우.","선율이 조금 바뀌며 경쾌해진다."
# "골목길을 돌면 아직 불이 켜진 가게.","호빵 기계 옆에 작은 눈사람이 하나 서 있다."
# "집 앞에 서서 벨을 누르려고 하다가 뭔가 이상한 현우.","주위를 둘러본다. 이사 간 옛날 동네에도 눈이 많이 왔었나보다."
# "TV는 저 혼자 돌아가고 있다. 애국가라도 나오는…","방안으로 들어오면 책상에 교통위반 딱지들이 수북히 쌓여있다."
# "그 중에 어떤 여자와 찍힌 사진.","현우 옆에 앉은 여자의 얼굴이 까맣게 가려져 있다."
# "S# 66. 현우네 새 집 - 아침","옷을 차려입고 나오는 현우. 트럼펫 케이스를 어깨에 메고 있다. 엄마가 밥상을 차려놓고 기다리고 있다. ""김이 나는 국도 놓여있고, 깻잎, 계란찜, 김치 등이 놓은 아침 밥상. "" 그 옆에 반찬통이 여러 개 탁자 위에 놓여 있다."
# "엄마","일어났니? 너 오는지두 모르구 깜빡 잠이 들었네…."
# "현우","나 그냥 가야 돼 엄마…. 시간 없어."
# "엄마 : 그래두 먹구 가….","현우 : 안돼… 기차시간 있어서 가야 돼. 전화할 게 엄마. ""엄마 : 얘, 그럼 저거 반찬이라도 가져가. 다 싸놨는데…. 응? """
# "현우","그거 가져가기 무거워."
# "엄마 : 별일 없는 거지? 엄마가 갈까 한번?","현우 : 거길 엄마가 어떻게 와. 조금 있으면 올 텐데 뭐. 참! 월급 받았거든…. 이거 엄마 용돈. ""엄마 : 아이구 됐네, 너 쓸 돈도 없을 텐데…."""
# "현우 : (억지로 쥐어주며) 받어.","""엄마는 더 이상 얘기 해봤자, 소용없다는 걸 아는지 그냥 가만 계시다."""
# "하얀 돈 봉투를 들고 선 엄마.","현우 : 저거 무슨 나무야? 엄마 : 글쎄…. 겨울이라… 나두 모르겠네. 봄 되고 꽃이 피어봐야 알지…."
# "S# 67. 관악실 - 낮","재일이 혼자 벽 앞에 선 채 뭔가를 보고 있다."
# "아무도 없는 관악부.","현우가 문을 열고 들어온다."
# """혼자 연습이라도 했는지,""","재일이 손엔 트럼펫이 꽉 쥐어져 있다."
# "현우","연습했니?"
# "재일","대회 포스터 나왔는데요."
# """현우가 재일이 옆으로 다가가보면,""","빨간 연주복을 잘 갖춰 입은 어느 학교의 관악부 모습이 담겨있는 대회 포스터가 벽에 붙어있다."
# "S# 68. 관악실 - 낮","진지하게 연습을 하는 아이들. 많이 좋아졌다."
# "제법 화음이 이루어지는 아이들의 연주.","용석이 자리는 비어 있다. ""은빛 트럼펫을 옆에 놓은 현우, 뭔가 마음에 들지 않는 표정으로,"""
# "현우","야 잠깐 잠깐."
# "아이들","……."
# """현우","악장, 용석이 왜 계속 안나오지? """
# "악장","……."
# "심벌즈 : 아빠가 못하게 한대요.",""" 현우, 다시 보면 악장과 심벌즈 모두 안대를 했다."""
# "현우","너흰 또 눈이 왜 그래?"
# "심벌즈 : 재일이한테 옮았어요.",""" 현우 보면, 쑥스러워하고 있는 재일. 안대는 없다."""
# """현우","그리고 너희들, 씽코페이션…, 씽코페이션이 뭔지 알아?"""
# "현우","니네 좋아하는 여자 생기면 뭐 하고 싶어?"
# "아이 1","극장가고 싶은데요?"
# "현우","말고."
# "아이 2","손잡고 싶어요."
# """현우","비슷한데…. 약해, 약해."""
# "아이 3","전… 뽀뽀하고 싶은데요."
# """아이들, 킥킥거린다. ""","""현우 : 오 오…. 그래 하고 싶겠지. 근데 그거 말고,"" 재일 : 끌어안고 싶다. 현우 : 그래. 그거야. 가까이 끌어당기고 싶잖아. 그럴 때 내가 저 여자를 씽코페이션 하고 싶다…. 그러는 거야. 니들 연주에서는 그게 빠졌어. 자 그 느낌을 살려서 다시 한 번."
# "셔터가 내려진 약국.","""불 꺼진 어두운 약국 안엔 빨간 전기난로 하나가 빛을 내고 있고,"" 그 옆에 현우와 수연이 커피 잔을 들고 둘러 앉아있다."
# "수연","한때는 상도 잘 타고 그랬는데…. 지금은 아예 인원도 모자라고…."
# "현우 : …….","수연 : 관악부만 그런 게 아니고 학교 자체가 그런데요 뭐."
# "현우","……."
# "수연","해가 다르게 사람들이 빠져나가니까…."
# "현우","수연씬 어때요?"
# "수연","네?"
# "현우","떠나고 싶은 마음 없어요?"
# "수연","……."
# "현우 : 아버지도 탄광에 안 나간지 꽤 되셨다면서요.","수연 : 글쎄요…. 언젠간 검은 산이 미워질 수도 있겠죠…."
# "현우","……."
# "수연","참…. 집엔 잘 갔다 오셨어요?"
# "현우","네."
# "수연","…… 만날 사람들 다 만나고 왔어요?"
# "현우","……."
# "수연을 데려다 주고 오는 현우.","트드득 트드득… 요란한 소리를 내며 밤거리를 달리는 현우의 차. 차도 한복판에 두 사람이 엎치락뒤치락 하고 있는 모습이 보인다. 술에 취해 몸을 못 가누는 아버지와 실랑이를 하고 있는 용석이다."
# "현우","아버님이셔?"
# "용석","… 예."
# "현우","약주를 많이 하셨구나."
# "무거운지 땀을 뻘뻘 흘리며 힘들어하는 현우.","용석은 미안해 어쩔 줄 모르겠으면서도 현우가 마냥 고맙다."
# "현우","… 너 아버지 업어본 적 있니?"
# "용석","……."
# "현우","생각보다 무거우신데? 아이고…."
# "용석","괜찮으세요?"
# "현우","그럼…. 아버지가 못하게 하시니?"
# "용석","… 네."
# "현우","… 왜?"
# "용석","헛바람 더 들기 전에 공부해서 상고 가래요."
# "현우","… 그래…. 그것두 좋아. 그래두 돼."
# "용석","싫어요."
# "현우","음악 계속 하구 싶어?"
# "용석","네…."
# "현우","왜? 케니 지?"
# "계장 : 천수형님～ 천수형님～ 손님 오셨어요.","사람들을 둘러보는 현우. 용석 아버지는 나타나지 않고 대신 검은 얼굴을 한 사람들이 궁금한 눈빛으로 현우를 돌아본다."
# "목욕탕으로 들어가는 계장.","현우도 따라 간다."
# "‘천수형님’을 외치는 소리에","자욱하게 끼어있는 수증기를 뚫고 누구 한명이 다가온다."
# "용석부","누가…."
# "옷을 다 벗은 채로 다가오는 용석 아버지.","현우 : 안녕하세요. 저 용석이 관악부 지도교사입니다."
# "악수를 건네는 손.","현우가 슬며시 손을 건네면 덥석 잡아 버린다."
# "용석부","어 그래. 거기두 인원보충 아직 안됐니?"
# "주호 : 네. 아직….","용석부 : 요 밖에서 잠깐 기다리슈. 내 금방 씻고 올 테니까."
# "현우","네."
# """S# 73. 사무실 옆, 테이블 - 낮""","깨끗해진 모습의 용석 아버지와 주호가 나온다."
# "용석부 : 참 요즘 보기 드문 놈이야. 저놈이.","화나면 성질이 지랄 같아 그렇지. 저 놈이 저러구는 가서 카센타도 한다니까. 잠깐만 있어 봐요."
# "벤치에 앉아 기다리는 현우.","""잠시 후 종이컵 두개와 소주 댓병, 김치 한 종지를 가져오는 용석 아버지."""
# "용석부","저 안에 들어갈 때 말야. 인차를 타고 들어가거든? 저거 보이지 노란색 차."
# "저 안에서 사람들이 그래요.",""" 인생은 30세 때는 30키로, 40에는 40키로, 50에는 50키로로 간다구. "" "" 용석이 그 놈, 지금 어릴 때 저렇게 지내다가 "" 어느 날 이게 아니었나부네 싶으면 늦은 거 아닙니까? 현우 : 네…. 근데 용석이는 소질이 있습니다."
# "용석부","소질…. 나도 있었지."
# "그래서 내 좀 알아요. 음악이란 거…. 좋지….","술에 취해 가지구 집에 들어와서 용석 에미한테 나팔을 불어주면 술주정을 집에까지 와서 하냐고 하면서도 좋아했지. 글쎄 그 재미로 나 같은 놈한테 붙어살았는지도 모르지만…. 호강한번 못해보고 그렇게 살다가 저거 하나 낳고 죽었어. ‘부’짜가 들어가는 직업은 사람이 할 짓이 아닌 거예요. 파출부… 청소부… 잡부… 광부! 용석이 녀석은 ‘사’짜 들어가는 직업을 갖게 하고 싶어요. 검사… 의사… 박사… 안 되면 최소한 장사라도 해야 할 거 아니요. 장사!"
# "현우 :   악사….","용석부 : 내가 두려운 게 뭔지 아쇼? 저 놈이 클 때까지 옆에서 지켜주지 못하면 어쩌나 하는 거요. 저 놈 클 때까지는 옆에 있어줘야지. 그게 내 지금 하나 남은 바램이요. "" 그래도 이런 아버지지만, 없는 것보다 있는 게 나을 테니까. """
# "현우","아이의 꿈을 꺾으시면 꼭 그렇지도 않죠…."
# "용석부","꿈?… 선생님은 꿈이 뭡니까?"
# "현우 :   예?","""용석부 : 하긴, 선생님은 훌륭한 부모님 만나서 곱게 자라면서 꿈을 이룬 거겠지."" 우리 같은 놈들은 꿈도 가려서 꿔야지. 나도 꿈이 있었지. 막장 인생이 내 꿈은 아니었거든. 꿈꾼다고 다 이루어집디까? 자식 생각 부모보다 더 하는 사람 있습디까? 우리 애는 보내지 않을 테니 그리 아쇼. "" 내 미안해서 그러니, 이거나 한잔 더 하구 갑시다. """
# "현우","……."
# "S# 74. 거리 - 낮  (눈)","학교 밖에 서서 현우를 기다리는 용석. 안대를 하고 있다. 눈 쌓인 거리를 걷는 선생님과 학생. 현우와 용석이다. ""문 닫힌 약국도 지나고, 약국 안을 용석이 몰래 들여다보고, "" ""길 건너 떡 팔고 있는 재일이 할머니도 보고, 철길도 지나고… """
# "현우","이번엔 너야?"
# "용석","……."
# "현우","에이 정말…. 드럽게."
# "용석","뭐 어때요? …치."
# "어떻게 됐어요?","""현우 : 니네 아버지…, 만나뵈니까 누군지 알겠더라. "" 지난번엔 깜깜한 밤이라 그리구 술을 너무 많이 드셔서 얼굴을 잘 못 알아봤는데…."
# "용석","예?"
# "현우","옛날에는 아주 유명하셨던 분이야."
# "용석 : 그래요?","""현우 : 응…. 알만한 사람은 다 알지. "" 암스트롱의 ‘헤븐스 도어’라는 곡이 있는데… 우리나라에서 그 곡을 제대로 연주하는 사람은 딱 한명밖에 없다고들 했거든…. 바로 니네 아버님이야."
# "용석 : (흐뭇해서 웃으며) 난 다 뻥인줄 알았는데….","""현우 : 야… 누가… 아버지가, 아들한테 뻥을 치는 아버지가 어딨냐?"" 용석아…. 아버지 말씀두 일리가 있더라구. 난 아버님이 용석이 너를 그렇게 사랑하시는 줄 몰랐어. 그냥 반대만 하시는 줄 알았는데…. 선생님이 할 말이 없더라."
# "용석 :  …….","현우 : 공부 열심히 해서 다른 일하면 좋지 뭐. 선생님 봐. 여기 와서 이러고 있잖니 ?"
# "용석","여기가 뭐 어때서요?"
# "현우 : 어… 무슨 말이냐면. 그게 말야….",""" 너 여자친구 맛있는 것두 사 주구, 선물두 펑펑 해주구 그러구 싶지 않니? "" 근데 음악하면 그게 잘 안되거든. 케니 지가 아무나 되는 게 아니야. 상고 가서 장사하면 돈 잘 벌잖아…. 수정이두 그런 거 원할 걸 아마? 용석 : 그런 게 뭐 중요해요. 나 그래서 때려쳤어요. 수정이."
# "현우 : 뭐? 왜?","""용석 : 나보다 나이두 한살이나 많은 게 맨날 뭐가 그렇게 불만인지,"" "" 연습하는데 만나자구 전화하구…. 칭얼거리기나 하구,"" "" 뭐 사달라 그러구, 뭐 없다구 짜증내구. "" 내가 뭐 재벌집 자식이에요? 광부집 자식이지! ""현우 : 그치… 넌 광부집 자식이지. 야, 그래두…. "" 얼마 전까지만 해두 좋다구 나팔두 불어주구 그러더니 고새 맘이 바뀌어서 여자를 버리냐? 남자가 그럼 안 되지. 안 그래? ""용석 : 버리긴 뭘 버려요. 무슨 물건이예요, 수정이가…. "" ""현우 : … 그치… 맞아 니 말이…. 너 있잖아, 그래두 그럼 안돼…."" 다시 한번 생각해봐. "" 이 놈아! 그래도 니가 좋아서 그랬으면 끝까지 책임을 져야 할 거 아냐, 남자가."" 용석 : 글쎄… 책임을 질수가 없다니까요! 무슨 책임을 져요. 제가 뭘 어쨌다구요."
# "현우 : 그렇다고 그렇게 마음이 확 확 바뀌냐?","용석 : 나는 그렇게 돈 많이 드는 애를 만날 수가 없다니까요. 선생님이 용돈 주실래요? 현우 : 그럼 수정이를 설득 해보든지. 그 애도 너 좋아하던 눈치던데."
# "용석","그리고 걔는 다리도 너무 짧아요."
# "현우","야… 고새 또 뭐가 잘못 되가지구는…."
# "용석","근데 선생님 왜 그렇게 흥분하세요?"
# "현우 : 어… 아니 그게 아니라….","티격태격… 되지도 않는 소리를 해가며 용석을 달래보는 현우. 눈발이 다시 조금씩 날린다."
# "S# 75. 자취방 앞 - 낮","""문 앞에 엄마가 배낭을 맨 채로 바닥에 쪼그리고 앉아 기다리고 있고, "" 두 보따리나 되는 짐이 대문 옆에 놓여있다."
# "현우","엄마!"
# "엄마","어… 이제 오니?"
# """현우 : 뭐 하러 왔어, 여기까지…. 추운데….""","""엄마 : 너 밑반찬도 없고, 뭐 먹고 사는지도 모르고…. "" 현우 : 이걸 다 어떻게 들고 왔어?"
# "엄마 : 무겁니? 이리 줘. 그럼. 내가 들게….","현우 : 됐어. 얼마 전에 갔다 왔잖아. 뭐 하러 와 오기를… 이 먼 데를. 에이 씨…. ""엄마 : "" … 이왕 엄마가 왔는데 짜증 좀 안내면 안 되니?"
# "현우","내일 갈 거야?"
# "엄마","가지 뭐해. 그럼."
# "현우","……."
# "엄마","……."
# "현우","엄마."
# "엄마 : 응?","현우 : 내가 첨에 음악 하겠다고 고집 부릴 때 어땠어? 속상했지?…"
# "엄마","속상하긴… 그렇게 좋아해서 하겠다는데…."
# "현우","……."
# "엄마 : 갑자기 왜? 애들 보니까 옛날 생각나?","""현우 : 아니 그냥…. 엄마, 엄마는 어렸을 때 꿈이 뭐였어?"""
# "엄마 : 꿈? 꿈은 무슨… 먹고살기 바쁠 땐데….","현우 : 그래도 어렸을 땐 무슨 꿈이 있었을 거 아냐…. ""엄마 : 엄마 학생 때, 글 잘 쓴다고 선생님 칭찬도 받고 그랬는데…."" 시인이나 소설가도 되고 싶었고… 선생님도 되고 싶었고…. 그때 생각하면 뭐하니…. 니 아버지 만나서는… 행복하게 사는 게 꿈이었고…. 그 다음엔 너 하나 잘되는 게 꿈이었지…. 우리 아들이 선생님 돼서… 엄마 꿈 하나 대신 풀어줬네…."
# "어느새…","달빛에 비친 현우의 눈가가 살짝 젖어있다."
# "김치. 콩자반. 보리차. 육포. 마늘 등등…","한없이 나오는 엄마의 꾸러미. 어떻게 저걸 다 들고 왔을까 싶다."
# "사진첩을 들여다보는 현우.","한 장 한 장 넘기면서 조금씩 표정이 부드러워진다."
# "사진을 보며 빙그레 웃는 현우.","중고등학교 때의 즐거운 모습들. 트럼펫 들고 친구끼리 장난치던 모습. 트럼펫 독주를 하는 모습. 환하게 웃고 있는 사진들이다."
# "마치 사진 속 현우처럼 즐거운 아이들의 관악실 풍경들.","여느 때와 같이 까불고 장난치고 즐겁게 놀고 있는 모습."
# "현우","뭐가 그렇게 즐겁니?"
# "아이들","심벌즈가 너무 웃겨요."
# """심벌즈, 애들 앞에서 귀여운 엉덩이춤을 추고 있다.""","현우도 희미하게 웃는다."
# """현우 : 심벌즈야, 넌 뭐가 그렇게 좋니? ""","심벌즈 : 용석이 땜에 대회는 다 글렀다구 애들이 너무 우울해 하잖아요. 그래서…."
# "현우","너네 또 연주하고 싶다고 했지?"
# "아이들","네!!!"
# "각자 집에서 연습을 하는 아이들.","제 악기가 들어 갈 선율에 그 악기를 연습하는 아이들이 보이고."
# "그리고 지하 갱도를 밝히며","리듬에 맞추어 움직이는 광부들의 헤드램프의 불빛들이 이어진다."
# "도시락으로 식사를 하는 사람들.","하얗게 웃음을 지으며 얘기를 나누고 있다."
# "“아버지한테 맞아 죽지 않을까요…”","“아버지한테 좀 맞으면 어때… 설마 아버지가 널 죽이기야 하겠냐?”"
# "광부들을 싣고 나오는 노란색 인차.","주호도 보이고 용석이 아버지도 보인다."
# "하얀 입김들을 쏟아 내는 사람들.","멀리 어둠 끝에 지상으로 통하는 작은 빛줄기가 보이기 시작한다."
# "점점 다가오는 빛줄기.","그 빛을 타고 관악연주도 조금씩 들리기 시작한다."
# """인차를 타고 밖으로 나와 보면, ""","갱도 중앙 광장에서 아이들이 연주를 하고 있다."
# "아이들의 연주가 울려 퍼지는 중앙갱.","""어떤 아버지들은 잠시 보다가 자기 갈 길을 가기도 하고, "" 또 어떤 아버지들은 모자를 벗고 아이들의 음악을 끝까지 들을 채비를 하기도 한다. 연주하는 아이들 하나하나의 면면… 조금 슬픈 듯 서정적인 음악. ""현우의 지휘도 여느 때보다 힘차고, 심벌즈도 박자를 제대로 찾는다. """
# "용석이를 보고 있는 용석 아버지.","용석이도 힘차게 연주를 하며 아버지를 보고 있다."
# "자취방 앞에 놓인 화분들.","엄마가 방을 나선다. ""어제 저녁 해놓은, 들통 가득 들어 있는 곰국에서는 아직도 김이 모락모락 나고,"""
# "엄마","쓰레기통은 제 때 제 때 비워. 방에 냄새난다."
# "현우","알았어."
# "S# 81.기차역 가는 길 - 낮","현우와 엄마가 온다. 기차역으로 가는데 재일이 할머니 있는 곳을 지나는 모자."
# "엄마","그냥 들어가. 엄마 여기서 가면 돼."
# "현우","괜찮아."
# "재일이 할머니 앞에 다가온 두 사람.","파란색 대야 안에 담겨 있는 온갖 종류의 색색가지 떡들. 지나가다가 떡들을 본 엄마는 그 앞에 쪼그리고 앉아서 구경을 하기 시작한다."
# "엄마 : 어머… 떡 색깔이 참 곱네요.","""할머니: 아이구, 선생님 어머니 되세요? """
# "엄마 : 네. 아세요?","할머니: 그럼요. 아다마다요. 여기서 아주 유명하신 분이신데…"
# "두 노인네의 닭살스런 대사가 낯간지러운지","현우는 엄마의 배낭을 들고 등을 돌려 서 있다."
# "엄마 : (기분이 좋아서) 그래요?","할머니: 내가 다 만든 거예요. 공장에서 만든 거랑은 맛도 틀려요."
# "엄마","이건 뭐예요?"
# "할머니","그건… 바보떡. 아주 담백하고 맛있어요."
# "엄마","이건요?"
# "할머니","그건 별슬기…."
# "엄마 : 음… 별게 다 있네요….",""" 얘, 이것 좀 사가지고 애들이랑 같이 먹어라."""
# """현우","아, 됐어…. 무슨."""
# """엄마","그러지 말고, 좀 가져가. 엄마가 사줄게."""
# "할머니","그래요. 내가 싸줄게."
# "엄마","할머니 올해 어떻게 되세요?"
# "할머니","죽을 때 다 되었소."
# "엄마","아직 정정하신데요 뭐."
# "할머니","어떻게 되셨수?"
# "엄마","저는 엊그제 육순 지났어요."
# "할머니 : 아이구… 새댁이구먼 아직….","엄마는 할머니의 말씀을 들어보란 듯이 현우를 돌아보고 수줍어 웃는다."
# "아직도 소녀 같은 엄마.","""할머니: 우리 같은 것들은 이리 가도 천하고, 저리가도 천한 거요. "" 어여 빨리 죽어야 할 텐데. ""엄마 : 아유, 정말 별 말씀을 다 하시네요. 그런 말씀일랑 다시는 하지 마세요."" 좋은 세상 오래 사셔야지요. 요고랑 조고랑… 좀 넉넉히 싸주세요."
# "할머니: (떡을 봉지에 담으면서) 오래살기는….",""" 요번 여름에 우리 착한 손주놈 하고 바다구경가기로 했는데, "" 그때까지만 살아도 고맙지…. 내가 빨리 죽어야 그 놈이 지 에미 찾아갈 텐데…. ""엄마 : 아이구, 왜 자꾸 그런 소리를 하세요, 할머니…."""
# "돈을 건네는 엄마.","할머니: 아이고 내가 무슨 돈을 받아요. 아니에요…. 그냥 가져가세요…. 선생님한테 무슨 돈을 받아요."
# "받을 돈을 받고도 민망해 하는 재일의 할머니.","할머니는 현우에게 돈을 건네주려고 한다."
# "기차가 멈춰있는 승강장.","배낭을 메고 떡 봉지를 달랑달랑 들고 엄마를 따라가는 현우. 손에는 기차표가 들려져 있다."
# "현우 : (배낭을 메주면서) 들어가.","엄마 : 현우야… 이 다음에… 엄마 죽으면 화장해라…."
# "현우","……."
# "엄마 : 아니… 그냥.","현우 : …… 나중에 엄마 보고 싶으면 난 어디로 가 그럼…. 왜 그런 소릴 하구 그래… 재수 없게…. 엄마 : 아니야 취소할게…. 그럼 됐지?"
# "현우","빨리 가…!"
# "은은한 미소를 짓는 엄마.","기차에 탄다."
# """자리에 앉는 엄마, ""","창 밖에 선 현우를 본다."
# "담배를 바닥에 내팽개치며 씁쓸해 하는 현우.","떡봉지만 달랑달랑 든 채 엄마를 쳐다보지 않는다."
# "S# 83. 관악실 - 낮","용석이 주변에 아이들이 모여 있다."
# "반짝반짝 빛나는 새 색소폰을 들고 있는 용석.","관악실로 들어오는 현우 손에 들려있는 재일이 할머니의 떡"
# """현우","옛다. 떡 먹어라!"""
# """아이들","와. """
# "몰래 빼내고 먹는 현우","""현우 : 당번 누구냐? """
# "용석이의 새 색소폰을 부럽게 만져보던 재일이.","깜짝 놀라 현우를 쳐다본다."
# "아이들 : 재일이요.","""현우 : 물 좀 떠 와라. 재일아."" ""재일이: 네…."""
# "현우","……."
# "“야! 저거 봐.”","창가에 있던 심벌즈가 소리치자 그쪽으로 우르르 몰려가는 아이들. ""창밖 저 아래에, 당직이 얼음판에 미끄러져 넘어져있다."""
# "다시 일어나려다 한 번 더 미끄러지고 마는 당직.","""용석, 어느새 잽싸게 새로 산 색소폰을 집어 들고는 "" 창가로 다가가 몸을 숨긴 채 연주한다."
# "다시 힘겹게 일어서는 당직.","""음악소리에 잠시 귀를 기울이며 갸우뚱 하는 듯하다가,"" 옷에 묻은 흙을 털어내기에 바쁘다."
# "어두운 병실.","수연이 아버지가 누워있는 침대 옆에 앉아있다."
# "약국 밖에서 떡 봉지를 들고 담배를 피우는 현우.","불이 켜 있고 “잠시 문 닫음” 이라고 써 있다."
# "현우","맨날 약국 비워두고 어딜 그렇게 가요?"
# "수연","춥죠? 밖에."
# "현우","네. 어휴… 여기 정말 춥네요."
# "수연","… 추워요 여기."
# "현우","여긴 겨울이 길죠?"
# "수연","네. 다른 데 보단 많이 길죠."
# "그래서 봄도 제일 늦고…. 그래도 오긴 와요.","현우 : 난 추운 게 차라리 더 나아요. ""수연 : ……."" 나두 그랬었어요. 봄이 오면 또 뭐 할 건가…. 허망하게 왔다가 가버리니까. 근데 요즘은 안 그래요."
# "현우 : 왜요?","수연 : … 글쎄요. 그냥 그래요. 그냥 오구 가구 그러는 거 같애요. 잠시 다녀가는 거죠 뭐. 현우씨처럼…. 그러다 또 오구…. "" 근데, 선생님은 소화제도 안사면서 요즘 여기 자주 오시는 것 같네요. """
# "현우","…… 언제 끝나요?"
# """수연","끝낼까요, 그만? 내 맘대룬데 뭐…."""
# "엄마가 사 주고 간 떡을 먹고 있는 두 사람.","수연 : 재일이 할머니는 재일이 엄마 소식 없나"
# "현우 : …….","수연 : 음반 저거 한 몇 장이나 돼요?"
# "현우","그건 뭐 얼마 안돼요."
# "수연","더 있어요?"
# "현우","서울에 많죠. 한 몇 천 장 돼요."
# "수연","잉? 그거 모으는데 얼마 걸렸어요?"
# "현우 : 한 15년 정도?","수연 : 어이그…. 나 같으면 라디오를 하나 사고 말겠다."
# "현우 : …….","방바닥에 놓여있는 트럼펫을 보며 언제 불어 줄 거냐는 듯 현우를 쳐다본다."
# """수연 : 선생님은 음악, 왜 하게 됐어요? ""","현우 : …. 모르겠어요. 잘 기억 안나요. ""수연 : 저 나팔, 저렇게 방바닥에 굴러다니면 안 되는 거 아녜요?"""
# "수연","살 흰 애 추억?"
# "S# 87. 언덕 - 밤","언덕길을 내려오는 현우. 길이 미끄러워 언덕 아래 차를 세워두었다. 추워서 몸을 움츠리며 내려오는데 웬 남자가 하나 길을 막아선다."
# "현우","누구…. … 아 안녕하세요!"
# "주호","수연이 만났어요?"
# "현우","… 네. 근데… 왜…."
# "주호","수연이하고 무슨 사이예요?"
# "현우","예?"
# "주호","수연이하고 무슨 사이냐구?"
# "현우","그걸 내가 왜 말해야 되죠?"
# "주호","수연이 좋아해요? 에?"
# "현우","……."
# "주호 : (흥분하기 시작) 같이 잤어? 응?","""현우 : … 이러지 마세요. """
# "주호","… 이 새끼가!"
# "S# 88. 파출소 - 밤","""얼굴에 상처투성이의 현우와 주호, 한쪽 의자에 나란히 앉아 있다."" 웬 취객 하나가 들어온다."
# "취객","나 자수하러 왔어요!"
# "취객","자수해서 광명 찾으라며? 나도 광명 찾을라고!"
# "순경 : …….","취객 : 자수할 게…. 십자수 할 게…. 광명을 찾아줘. 자수하라며? 십자수 하겠다니까! 니미～"
# "한마디 대꾸도 없이 취객을 끌고 밖으로 나가는 순경.","순경 : 학교 선생님이 싸움질을 하시면 어떡합니까?"
# "현우","싸우긴 뭘 싸워요. 두드려 맞았다니까!"
# """순경","주호, 너도 제발 말썽 좀 그만 피우고!"""
# "주호","수연이한테는 말하시면 안돼요."
# "순경 : 새끼….","주호 : 진짜 안돼요. 그럼 저 진짜 끝장이에요."
# "순경 : 그럼 니가 먼저 사과드려. 빨리.","파일북으로 주호의 머리를 탁 치는 모습이 꼭 형 아우 같다."
# """마지못해 현우에게 손을 내밀어 악수를 청하는 주호,""","주호 : ……. 미안합니다."
# """역시 마지못해 주호의 손을 잡는 현우,""","주호 : 저기요…. 앞으로는 수연이 좀 그냥 좀 놔두십쇼. 부탁입니다. "" 수연이 걔, 그런 애 아니에요… 착한 애예요. "" 제발 부탁합니다."
# "현우 : …….","주호 : 저는… 수연이 없으면… 진짜 아무 것도 없는 놈이거든요. 걔… 그런 애 아니에요…. 괜히 그러지 마세요."
# "현우","……."
# "순경","가 봐. 너 내가 지켜 볼 거야."
# """순경에게 꾸벅 인사하고 파출소를 나가는 주호,""","순경 : 그래도 저 자식이 수연씨를 얼마나 끔찍하게 생각하는지 몰라. 술두 안먹구. "" 수연씨 아버지가 병원에 있는지 오래 됐는데, "" "" 맨날 가서 출근부 도장 찍는다고 병원에서 소문 다 났어요, 저놈 저거…. """
# "현우 : 어디가 불편하신가요?","순경 : 여긴 대부분 다 진폐증 환자들이에요. 딸내미 하나 있는 게 수연씬데.. 그 여자두 아버지 땜에 여기 붙박혀가지구…."
# "현우","……."
# "장사를 끝내고 짐 정리해서 돌아가는 재일이 할머니.","길 건너에 용석이가 옷을 깨끗하게 입고 누군가를 기다리고 있다."
# "뒤에는 빨간 색 장미 한 다발을 숨기고 있는 용석이.","""아이들이 지나가며 뒤에 뭐 있나 보자고 장난을 걸고, "" 안 보여주려고 숨기는 용석. 조금 부끄러운 모양이다."
# """아이들 저희들끼리 웃으며 가고, ""","멀리서 수정이가 가벼운 걸음으로 다가온다."
# "할머니는 눈이 부신지 손가리개를 하고","지는 해를 보고 계시다."
# "얼굴이 조금 상한 현우.","그 옆에서 재일이가 밥풀을 튀겨가며 TV를 보고 있다."
# "깔깔대는 재일이.","재일 : 선생님 더 있어요? … 좀 더 주세요."
# "현우 : 그래….","나가서 곰국을 더 퍼 담으면서도 TV를 보고 있는 현우. 현우의 휴대폰이 울린다."
# """재일","선생님, 전화 왔어요. """
# "현우","어… 그래."
# """소금도 가져다주고, 파도 가져다주고… ""","재일이는 계속 재밌게 TV를 보다가 웃고 밥 먹고 그러고 있다."
# "몇 발짝 걸어가다가 걸음을 멈추는 현우.","구름에 가려져있던 해가 나온다."
# "S# 92. 관악실 - 낮","현우가 애들을 앞에 두고 얘기를 하는 중이다."
# "현우","에릭 클랩튼 있잖아."
# "아이들","……."
# "현우 : 사람들이 잘 모르는 건데 이건….","에릭 클랩튼이 아들을 잃고 난 다음에 한참 방황할 때 말야. "" 자꾸 아들 생각이 나서 그 동네에서 못 살겠어서 이사를 갔는데, "" 그 이사 간 집 옆 건물에 기타 학원이 있더래. 그래서 거길 지나다 들러서 등록을 했거든. "" 근데 거기는 중국인 할머니가 기타를 가르쳤는데, "" 그 할머니한테 에릭 클랩튼이 기타 못 친다고 엄청 구박을 받았대. 그 담부터 다시 기타를 손에 잡은 거야…."
# "아이들 : …….","현우 : 진짜야. 그래서 “티어즈 인 헤븐”이 나온 거 아니냐."
# "아이들","……."
# "현우","그러니까 우리두 잘해보자. 알았지?"
# "심벌즈","에릭 클랩튼이 누구예요?"
# "현우","… 그런 사람 있어."
# "아이들","……."
# "현우","…. 오늘은 그만할까?"
# "현우 : 재일이 있니?","재일이가 문을 열어 준다. 재일이 얼굴이 의외로 맑다."
# "현우","엄마 보고 싶지 않어?"
# "재일","할머니가 보고 싶지 왜 엄마가 보고 싶어요?"
# "현우","……."
# "재일","할머니가 나 바다 데려간다고 했었어요."
# "현우 : 바다 안 가봤어?","재일 : 가봤어요…. 근데 할머니가 나랑 같이 가고 싶어 하셨어요."
# "현우","… 그래? 우리 언제 한번 같이 가자… 그럼."
# "재일 : 할머니가 안 계시잖아요.","말 없는 두 사람. 현우 라면을 내려놓는다."
# "현우","…… 후…."
# "재일","… 왜 그러세요?"
# "현우","그냥."
# "재일","그냥이 어딨어요. 다 이유가 있지."
# "현우","그냥… 사는 게 힘들어서…."
# "재일","…………."
# "현우","………?"
# "재일 : ……. 왜 그렇게 슬픈 얘기를 하구 그래요….","울음을 참던 재일이의 옷소매가 눈가로 올라간다. 재일이가 운다."
# """현우","미안해, 재일아……. 미안해."""
# "재일 : 나두 힘들어 죽겠어요.",""" 아, 아직… 트럼펫도…. 못 불어드렸단 말이에요…."""
# "현우","힘들어두 참아야지 어떡해 그럼."
# "재일","……. 알았어요."
# "S# 94. 술집 - 밤 (눈)","혼자 술집에서 소주 한잔을 앞에 놓고 있다."
# "현우 : 나야…. 잤어?","엄마 : 잠이 안와서 테레비 보는데 왜? 무슨 일 있니?"
# "현우","그냥…."
# "엄마는 어디 아픈 데 없어?","엄마 : 아픈 데가 왜 없니…. 이 나이 되면 여기저기 성한 데가 없지."
# "현우","뭐… 약 같은 것 좀 먹고 그러지."
# "엄마","약은 무슨…."
# "현우","엄마 영양제 하나 사 주면 먹을래?"
# """엄마","아이구, 먹지 그럼 안 먹어?"""
# "현우","… 엄마!"
# "엄마","응?"
# "현우","엄마 나 사랑해?"
# "엄마","미친놈…."
# "현우","……."
# "엄마","현우야…."
# "현우","…."
# """엄마","현우야, 무슨 일 있니? """
# "현우","아니……."
# "엄마","뭘?"
# "현우 : 그냥 뭐든지.","엄마 : 어이구…. 너는 지금이 처음이야. 뭘 처음부터 다시 시작해."
# "S# 96. 파라다이스 캬바레 안 - 밤","술에 취해 땀까지 흘려가며 열정적으로 연주하고 있는 현우. 색소폰이 아닌 트럼펫이다."
# "S# 97. 관악실 - 낮","아이들도 현우도 다들 힘이 없어 보인다. 재일이 자리가 비어있다."
# "현우 : (악장에게) 재일이 연락 없니?","심벌즈 : 저… 선생님… 재일이가요…. 선생님 트럼펫을 훔쳐갔는데요…."
# """용석","너 이 새끼, 훔쳐가긴 누가 훔쳐가."""
# "S# 98. 관악실 앞 계단 - 낮","소리가 조금 새는 듯한 트럼펫 소리가 들린다."
# "현우가 가끔씩 흥얼거리던 연희의 음악.","누군가 다가가 문을 살며시 열어보면… 이내 멈추는 연주."
# "현우","… 오셨어요?"
# "수연 : 제가 들어 드릴게요. 마저 해 주세요.","현우 : … 나중에 들려드릴게요."
# "수연","왠지 여기 계실 것 같아서요…."
# "현우","……."
# """수연","너무 걱정하지 마세요, """
# "현우","……."
# "수연","별 일 없을 거예요. 속이 깊은 애니까…."
# "현우 : 그럼요….","수연 : 그건 재일이 오면 들려주세요."
# "현우","… 네…."
# """수연이 학교 정문을 빠져 나와 걸어오는데, ""","그 옆에 소형 승용차 한 대가 선다."
# "“저기요”","수연 돌아보면 연희가 창밖으로 고개를 내밀고 웃고 있다. 연희 옆에는 경수가 타고 있다."
# "연희","여기 도계중학교가 어디예요?"
# "수연","바로 저거요."
# "연희 :  네 고마워요.","수연을 지나온 연희. 학교 앞에 차를 세운다."
# "경수","학교에 아무도 없을 텐데…. 관악부를 어디서 찾냐…."
# "연희","뒤져보다가 음악소리 나는 데만 따라가면 되잖아."
# "경수 : … 근데 너… 진짜 보러 안 갈 거야?","""연희 : … 응. 저기, 경수오빠…. 오빠한테 나랑 같이 온 거 말하지 말어. "" 경수 : 그래. 그냥 서울 갈 거야 그럼? 운전을 좀 쉬어야지. 연희 : 바람 좀 쐬고 가지 뭐. 꼭 약속이다… 알았지?"
# "경수 : 그래… 조심해.","연희 : 응. 간다."
# """경수","그래두, 뭐… 전하고 싶은 말 없어? """
# "연희","그런 게 있으면 내가 갔지. 갈게 오빠."
# "경수","응 그래."
# """연희 차 출발하고, 에휴~ 하는 경수. ""","수연을 지나쳐가던 연희. 다시 차를 세운다."
# """연희","저기요. 죄송해요, 자꾸. """
# "수연 : 네… 아니에요.","연희 : 여기서 제일 가깝구 가볼만한 바닷가가 어디예요?"
# "S# 100. 횟집 - 낮","수연과 같이 왔던 횟집에 현우와 경수가 앉아 있다."
# "현우","바다 처음 보냐?"
# "원샷으로 소주를 한잔 들이키는 경수.","""현우 : 천천히 마셔라… 야, 너 거기 무대엔 계속 서냐?"""
# "경수 : 무대 ? 어….","근데 웬일이냐. 밤무대라고 안 그러고…."
# "현우","아니 뭐… 내가 말만 그렇게 한거지 임마…."
# """경수 : 철들었네, 자식….""","현우 : 우리 음악 안했으면 뭐하고 있을까? 너 그런 생각해본 적 있어? 지금보다 행복했을까? 경수 : 갑자기 왜이래…? 행복은 무슨… 연애를 해야 행복하지…. … 나…. 만나는 여자가 있었는데…. 어제 헤어졌다. 한 2년 됐나?"
# "현우","2년? 근데 내가 그동안 몰랐단 말야?"
# "경수","그냥 뭐… 내가 얘기를 안 했으니까…."
# "현우","왜 얘기 안했어?"
# "경수","……."
# "현우","응?"
# "경수","결혼한 여자거든."
# "현우","뭐?"
# "현우 : 어… 이 새끼 봐라… 이거….","현우 : … 그래서 그동안 몰래 만났던 거야? 나한테도 말 안하고? 경수 : 몰래… 라기보다는… 그냥…. 유부남이랑 유부녀랑 바람피우는 거…. 단지 그렇게만 보이는 게… 싫어서…. 현우 : 그게 유부녀랑 유부남이랑 바람피우는 거지 뭐야 새꺄. 이게 아주 순…. 경수 : 내가… 되게 많이 좋아했거든. ""현우 : 야, 그래두 그렇지. 경자씨한테 안 들켰어? 한번두? """
# "경수","……."
# "현우 : 너 그럼 안 돼지.",""" 밖에 나가서 딴 여자랑, 것두 유부녀랑 그 짓을 한단 말야? 나쁜 놈이네 이거. "" 경수 : 야 새꺄! 넌 그럼 식구끼리 그거를 어떻게 하니?"
# "현우 : 뭐?","경수 : 아 씨발. 이거 세 병만 먹자고 정해 놓고 먹으니까 더 취하네. "" 너 있잖아, 니 인생 꼬였다고 내 인생 꼬이게 하지 마라. 무슨 말인지 알지? "" 난 우리 경자랑 잘 살 자신 있어… 알아? 너만 입 다물고 있음 돼."
# "현우","식구끼리는 그거 하는 거 아니래매!"
# "S# 101. 바닷가 - 낮","해변가 끝 쪽 한구석에 재일이가 혼자 앉아 트럼펫을 손에 꼭 쥐고 있다."
# "트럼펫을 쥐고 있는 아이를 보고… 지나치다가…","다시 가서 옆으로 다가간다."
# "연희","여기 앉아두 되니?"
# "재일","네…."
# "연희","…… 여기서 뭐해? 혼자?"
# "재일 : …… 그냥요.","""연희 : 왜, 누가 때렸어? """
# "재일 : 아녜요. 그런 거 없어요.","""연희 : … 너 나팔 잘 부니 ? """
# "재일","…… 이건 나팔이 아니라 트럼펫이에요."
# "연희","…… 응 그래. 트럼펫…."
# "재일","……."
# "연희","싫어 ?"
# """재일","저… 그럼, 저 차비 좀 주실래요? """
# "연희","…… 차비?"
# "재일","……."
# "연희","얼마나 있어야 되는데?"
# "재일","천삼백원이요."
# "연희","그럼 나팔 불어줄 거야?"
# "재일 : …… 네.","연희 : 그럼 먼저 불어주면 줄께. 차비 줬는데 그냥 가면 어떡해?"
# "재일","……."
# "연희","너 불고 싶은 거 불어줘."
# "재일 : …….","재일이가 트럼펫을 분다."
# "연희 : ……!","재일이의 트럼펫소리가 바닷가 한 구석에서 울려 퍼지는데…. 현우가 흥얼거리던 음악보다 훨씬 빠르고 경쾌해진 연희의 곡이다."
# "할머니에게 부는 건지 연희에게 부는 건지 모를","재일이의 트럼펫 소리가 바닷가에 울려 퍼진다."
# "지나가다가 발걸음을 멈추는 몇몇 연인들.","웬 여자와 나팔 부는 소년의 이상한 모습에 호기심을 갖고 보고 있다."
# "연희","……."
# "S# 102. 바닷가 - 밤","폭죽 소리 너머 낮게 연희의 음악이 들려온다."
# "현우","?"
# "점점 더 많은 폭죽을 터뜨리는 사람들.","폭죽소리에 묻혀 잘 들리지 않는다."
# "경수","저것들 아가리에 폭죽을 18연발씩 날려야 한다니까."
# "현우 : …….","""경수 : 너 연희 있잖아…. 버린 거냐, 놓친 거냐? """
# "현우","…… 너 이 소리 들리니 ?"
# "경수","무슨 소리? … 폭죽 소리?"
# "현우 : 아니… 나팔소리.","낮게 들리던 트럼펫 소리 멈춘다."
# "경수","헛소리 하지 말구 내 말 들어. 뭐든지 확률은 50프로야…. 되든지 안 되든지…."
# "현우","……."
# "S# 103. 해변가 식당 - 밤","연희와 재일이가 앉아 떡볶이를 먹고 있다. 식당 밖으로 현우와 경수가 지나간다."
# "연희","아줌마 여기 일인분만 더 주세요."
# """재일","네, 저두요. """
# "연희","오뎅두 2인분 주세요."
# """재일 : (연희보고) 저기요, 아줌마….""","""연희 : 어머? 얘 봐. 누가 아줌마야? 누나야, 누나!"" ""재일 : 네, 누나…. 나 궁금한 거 하나 있는데요. """
# "연희 : 응. 뭔데.","""재일 : 그거, 쫄바지 입고도 겨울에 여자들은 안 추워요?"""
# """연희","이거? 이거 쫄바지 아니야, """
# "꽃바지야 꽃바지!",""" """
# "S# 104. 도로 - 밤","아무 것도 없는 깜깜한 국도. 가로등도 없다."
# """경수","야, 너 괜찮아? """
# "현우","나 별루 안 먹었어."
# "경수 : 뭐 이렇게 헤드라이트가 변변찮냐… 뭐 보여?","하나 남은 헤드라이트가 또 나간다."
# "현우 : 아～ 새끼…. 그니까 너 입 좀 조심해.","""경수 : 야, 세워! "" 현우 : 거 봐라 임마. 아… 정말…."
# "국도변 풀섶에 나와서 오줌 누는 현우. 까만 실루엣.","경수는 몸을 구부린 채 토하고 있다."
# "등을 두드려 주는 현우.","현우 : 뭐 먹구 살 거 있다구 그렇게 처먹냐 처먹길…."
# "경수","아 씨발. 암것두 안보이니 어떡하냐."
# "현우","하던 거나 마저 해 . 뭐 어떻게 되겠지?"
# "경수 : 웩～","멀리서 헤드라이트를 켜고 차 한 대가 달려온다."
# """현우","어… 빨리 해, 새꺄! 저거 따라가야 돼. 빨리! """
# "경수","아～ 정말…."
# "차로 들어가는 현우.","현우네 차 옆을 지나가는 차 한 대. 경수 서둘러 뛰어와 타면"
# "S# 105. 차 안 - 밤","재일이는 안전벨트를 얌전히 매고 운전하는 연희를 가끔씩 쳐다본다."
# "연희","너 혹시 도계 중학교 다니니? 너 거기 관악부야 ?"
# "재일 : 네. 아세요?","연희 : 아니. 그냥 조금…. 너 아까 그 곡 어디서 배웠어 ?"
# "재일","우리 선생님한테서요. 좋죠?"
# """연희","…… 근데 그게,…."""
# "재일","원래 조금 느린 건데요…."
# "연희","그래?"
# "재일","근데 왜 누나는 아까 울었어요?"
# "연희","누가 울어?"
# "재일","아까 울었잖아요."
# "연희","… 어머 얘 봐…. 누가 울었다 그래…."
# "재일 : …….","카오디오에 반쯤 튀어나온 테입을 또 툭 집어넣는 재일이. 정훈희의 <꽃길>이 흘러나온다."
# "재일","이거 무슨 노래예요?"
# "연희 : 옛날에 친구가 나 들으라고 녹음해 준 거야….","재일 : ……. 좋다."
# "연희","좋지?"
# "S# 106. 도계 입구 - 밤","연희의 차가 멀리 선다."
# """읍내로 방향으로 가고, ""","재일이가 내린다."
# "재일","고맙습니다."
# "연희","그래."
# "재일","조심해 가세요."
# "연희","……."
# "연희 차 멀어지다가 멈추어 서는 연희 차.","다시 뒤로 붕~ 다가오더니 명함을 하나 건넨다."
# "연희","너 있잖아. 서울 오면 누나한테 전화해 알았지?"
# "재일","네…."
# "현우 : 너 올 때 뭐 타구 왔어?","""경수 : 어? … 기차 타구 왔지, 말 타구 왔겠냐, 그럼? 왜?"""
# "현우 : 근데 올라갈 기차표두 안 끊구 왔어?","""경수 : …… 얌마, 친구 만나는데 어떻게 시간을 정해놓구 만나냐?"""
# "현우 : 그러니까 그냥 자구 가!","""경수 : 자식아, 내가 이쁜 내 마누라 놔두고 왜 너하고 자냐?"" 현우 : 그래… 잘가라. 경자씨한테 잘 해주구…."
# "경수","저 있잖아. 그게…."
# "현우","왜 뭐 잊은 거 있어?"
# """경수","저기, 연희 있잖아. """
# "현우","……."
# """경수","사실은 말하지 말라 그랬는데,"""
# "현우 : …….","경수 : 그 결혼 안하기로 했대. 피아노 학원 다시 열었다고 하더라…. 현우 : ……. 넌 자식이 왜 그렇게 입이 가볍니?"
# "경수 : ……. (웃으며) 미안하다. 갈게 그럼.","""플랫폼으로 들어가던 경수, 현우 쪽으로 뒤돌아보더니,"""
# "경수 : 야! 그래도 음악 좋～잖아? 어?","하던 거 그냥 하자 씨… 이제부터 잘하면 되는 거 아냐?"
# "S# 108. 관악실 - 낮","현우가 관악실로 들어가면서 제일 먼저 보는 재일이 자리. 재일이가 웃고 있다."
# "담담하게 자기 자리로 가는 현우.","현우 자리엔 재일이가 가져갔던 트럼펫이 놓여있다."
# "심벌즈","선생님. 재일이 왔어요."
# """현우","어 그래…. 재일이 어디, 갔다 왔니? """
# "재일","네."
# "기쁜 마음으로 연습에 몰입하는 아이들.","자꾸 트럼펫 쪽에서 재일이가 실수를 한다."
# "현우 : 그만 그만….",""" 재일이 쪽으로 걸어가는 현우, 재일이에게 아프게 꿀밤을 먹인다."""
# "현우","왜 자꾸 틀리는 거야? 그렇게 하면 안 된댔잖아."
# "현우 : 자. 선생님이 하는 거 잘 들어봐.","재일이의 트럼펫을 뺏어드는 현우. 연주를 시작한다."
# "무언가에 몰입되어 있는 듯한 느낌을 주는 현우의 연주에","아이들 모두 푹 빠져 든다."
# "용석이는 몽롱한 표정으로 아예 턱을 괴고 듣고…","그럴 즈음 딱 끝나버리는 현우의 연주. 아이들 난리가 났다."
# "“더 해 주세요.”","""현우 : 자 자, 그만! 뭐 하는 거야? 이놈들이."" 재일이 잘 들었지? 뭐가 다른지 알겠어?"
# "재일","네…. 진심이요."
# "현우 : 아쭈….","현우의 메시지 벨이 울린다."
# """애들 보고 웃는 현우, 창밖을 잠깐 보더니, ""","다시 트럼펫을 입으로 가져간다."
# "해질녘의 하늘을 배경으로 혼자 난간에 앉아 있는 수연.","동네에 가로등이 차례로 들어온다."
# """현우","야, 너네들…. """
# "용석","왜 저를 보세요?"
# "심벌즈","학교에선 안 마시는데요."
# "현우","이거 사람들이 알면 퇴학이지… 나…."
# "아이들 : 네.","현우 : 눈병은 돌다 돌다 이제 다 끝난 모양이네?"
# "현우","긴장돼?"
# "아이들","……."
# """현우","걱정하지 마. 우승하지 뭐, 까짓 거. """
# "아이들","……."
# "멀리서 약국을 바라보며 서성거리는 현우.","수연이 정리를 하고는 불을 끄고 나온다. 약국 셔터를 내리려는 수연에게 현우가 다가간다."
# "현우","좀 도와드릴까요?"
# "수연","잘 하지도 못하면서…."
# "현우","재일인 뭐해요?"
# "수연","자요. 내일 대회라구 일찍 잔대요."
# """현우","잘 하는데요, 뭘…."""
# "수연씨 잘 따르죠?","""수연 : 그럼요, 우리가 원래 얼마나 사랑하는 사인데요. 선생님 오시기 전부터."""
# "현우","……."
# "수연 : …….","편한 얼굴로 걷고 있는 두 사람을 감싸고 있는 도계의 밤."
# "수연","… 추운데 들어가세요."
# "현우","……."
# "조금은 긴장된 아이들과 현우.","창 밖으로 시선을 두고 있는 아이들. 현우가 입을 뗀다."
# "현우","너네 그 옷 괜찮니? 관악복두 없이."
# "심벌즈","뭐 어때요! 멋있잖아요."
# "빰빠 빰빰… 빰 빰 빰… 딱 딱… 등등…","입으로 낼 수 있는 소리를 동원해 박자를 맞추어 보는 관악부."
# "정말 즐겁게 난리를 치며 박자를 맞추어보는 아이들.","버스가 대회를 향해 달린다."
# "초등학생부터 일반까지 전부 참여하는 가장 큰 대회.","전국에서 내로라하는 관악부들이 단복을 쫙 빼입고 국립극장 계단 곳곳을 점령하고 있다."
# """몇 명은 따로 떨어져 나와서 웃고 장난치고,""","심벌즈가 또 그 엉덩이춤을 추고 있다."
# """관악부 아이들, 서로 무스를 뺏어 바르느라 난리다.""","""다른 학교 관악부 애들이 교복 촌스럽다고 흉보며 지나가는데,"""
# "객석에 서서 무대를 바라보고 있는 현우.","감개가 무량하다."
# "S# 115. 무대 뒤 - 낮","""무대에 올라 연주를 하고 있는, 서울 남녀공학 고등학교 관악대."" ""40여명이 넘는 규모에, 멋진 단복. 연주도 훌륭하다. """
# "현우","떨려? 겁먹을 거 없어. 괜찮아."
# """정작 본인은 긴장된 얼굴로 긴 숨을 내쉬는데,""","아이들한테 떠밀린 악장이 다가온다."
# "악장","저… 선생님."
# "현우 : 어? 왜?","악장 : 저… 이거… 애들하고 같이 준비했거든요."
# """‘도계중 만세!’, ‘선생님 감사합니다.’""","""용석 : 선생님, 지휘는 폼으로 하는 게 아니에요. 너무 폼 잡지 마세요."""
# "긴장된 얼굴로 걸어 나오던 현우는","맨 앞줄에 앉아 박수를 치는 엄마를 보고 환하게 웃어 버린다."
# "작은 자동카메라를 들고 있는 엄마도 환하게 웃고.","아이들도 약간 들뜬 표정으로 무대에서 자기 자리를 찾아 앉는다."
# "지휘봉을 움직이는 현우.","그동안 연습했던 힘찬 행진곡이 터져 나온다."
# """아이들의 연주 흐르면서,""","그 동안 현우가 지나왔던 공간들이 보여진다."
# "잠든 아이들도 보이고… 담담한 아이들의 표정.","현우도 담담하다. ""한쪽 눈이 가려운지, 손으로 눈을 비비고 깜빡여보는 현우."""
# "모래사장에 자빠지고 서로 밀고 하는 즐거운 모습들.","해가 넘어 가고 있다."
# "현우와 재일이가 앉아 아이들을 보고 있고.","""현우 : 참, 재일아, 선생님 트럼펫 있잖아. 그거 줄 테니까 너 써라."""
# "재일","정말요?"
# "현우 : 그래….","재일 : 아니요…. 그냥 저는 선생님이 고쳐준 게 더 좋은데요. 현우 : 그래? 저기 그리구… 저… 일부러 그런 건 아닌데…."
# "재일","네?"
# "현우 : 서울대…. 선생님… 서울대 안 나왔거든?","재일 : 저… 지난번에 바닷가에서… 어떤 아줌마를 만났는데요."
# "현우","……."
# "재일","아… 아줌마 아니라 그랬구나."
# "현우 : 수연이 누나보다 더 ?","""재일 : 그만큼 예뻤어요. 참, 명함 받았는데 선생님 드릴까요?"""
# """현우","됐어, 임마."""
# "재일","근데… 울고 있더라구요."
# "현우 : 왜?","재일 : 모르겠어요. 선생님한테 배운 곡 연주했더니 울더라구요."
# "현우","……."
# "재일","좋은 아줌마던데… 왜 우는지 모르겠어요."
# "현우","……."
# "재일","사람들은 다 슬픈 일들이 있나 봐요."
# "현우","……."
# "수연","어서오세요."
# "현우","안녕하세요."
# """수연","고생하셨어요, 그동안. """
# "현우","한 것도 없는데요 뭐…. 대회도 떨어지고…."
# "수연","……."
# "현우","저… 수연씨…."
# "수연 : 네?","""현우 : 아니에요."" ""수연 : 싱겁기는…. 한참 가실 텐데, 밥은 드셨어요?"""
# "현우 : 네? … 아뇨.","수연이 난로 위에 올려져 있던 작은 냄비 뚜껑을 열어보면 냄비 속 누룽지에서 김이 모락모락 올라오고 있다."
# "현우 : 누룽지?","수연 : 지금 막 먹으려던 참인데…. 이거나 드시고 가세요. 현우 : 그럴까? 맛있겠네…."
# "수연","근데 눈은 왜 그러세요?"
# "S# 120. 카센터 - 낮","주호가 현우 차의 헤드라이트를 손보고 막 일어서고 있다."
# "헤드라이트의 불을 껐다 켰다 해보는 현우.","한쪽 눈엔 안대를 차고 있다."
# "주호","죄송해요."
# "현우","뭘요…. 점심은 드셨어요?"
# "주호 : 아뇨.","현우 : 수연씨 맛있는 거 먹고 있던데…. 가서 같이 드세요. 혼자 있던데."
# "주호","예…."
# "현우 : …….","주호와 멋쩍은 악수를 하는 현우. 두 사람 마주보고 웃는다."
# "근엄한 표정을 짓는 선생님들과 아이들.","그 맨 아래 엉망으로 엉켜 찍은 현우와 아이들의 사진이 붙어있다."
# "벽에는 계란판도 잘 정렬되어 붙어있고…","악기들도 낡았지만 윤이 흐르고 있다."
# "도계를 떠나는 현우.","점점 멀어진다."
# "S# 123. 현우네 새 집 - 낮","집에 아무도 없다."
# "걷다가 눈부신 하늘 한번 올려다보고는","""햇살이 따뜻한지, 입고 나왔던 겨울 겉옷을 벗어 팔에 걸친다."""
# "현우","거기서 뭐해?"
# "엄마","왔니? 눈은 또 왜 그래?"
# "현우 : 몰라… 별거 아니래….","""엄마 : 에이구…. 현우야, 이거 봐라. 이거, 엄마가 다 심은 거…."""
# "현우 : (역시나 엄마는 못 말린다 하는 웃음)","""현우, 가게에 들어가 담배를 하나 사 가지고 나온다."" 담배를 물고 신문을 하나 사 들고 걸어가는 현우 머리 위로"
# "저게 무슨 나무냐고 묻던 그 나무에","복사꽃이라도 환하게 피어있다."
# "S# 125. 연희 집 앞 - 낮","링겔 꼽혀있던 그 나무 아래 서서 올려다보고 있는 현우."
# "역시 벚꽃이 활짝 핀 나무.","벤치에 앉아 있던 현우 시야에 시장을 다녀오는 연희가 보이고…."
# "나무 뒤로 숨는 현우.","잠시 아쉬운 듯 연희가 사라진 현관을 바라본다."
# "느릿한 걸음으로 걷다가 문득","가방을 놓고 온 것이 생각난다."
# "연희","………."
# "현우","여보세요?"
# "연희 : ……….","현우 : 사람이 전활 받았으면 대답을 해야 할 거 아냐. 대답을…"
# "연희","… 왜 걸었어?"
# "현우","왜 걸긴…. 뭐 하냐?"
# "연희 : …….","현우 : 바뻐? 이따 술이나 한잔 할래? … 시간 있어?"
# "연희","술은 갑자기 왜…?"
# "현우","왜는 뭐가 왜야…. 그냥… 봄이잖아…."
# "연희","……."
# "현우","트럼펫이나 색소폰 같은 거는 안 가르치니?"
# """오월의 눈부신 태양 아래, 봄을 걷고 있는 사람들.""","바람에 날리는 악보집… 한 장 한 장 넘어간다."
#
#
# CSV 파일 '[대본]꽃피는봄이오면.csv 생성 완료.
